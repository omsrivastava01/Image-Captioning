# %% [markdown]
# <a href="https://colab.research.google.com/github/omsrivastava01/Image-Captioning/blob/main/Image_Caption_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization

seed = 111
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# !wget -q https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip
# !wget -q https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_text.zip

# %%
# !unzip -qq Flickr8k_Dataset.zip
# !unzip -qq Flickr8k_text.zip

# %%
# !rm Flickr8k_Dataset.zip Flickr8k_text.zip

# %%
IMAGES_PATH = "Flicker8k_Dataset"

IMAGE_SIZE = (299, 299)

VOCAB_SIZE = 10000

SEQ_LENGTH = 25

EMBED_DIM = 512

FF_DIM = 512

BATCH_SIZE = 64
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE

# %%
ls
# Out:
# CrowdFlowerAnnotations.txt  Flickr8k.lemma.token.txt   __MACOSX/
# ExpertAnnotations.txt       Flickr_8k.testImages.txt   readme.txt
# Flicker8k_Dataset/          Flickr8k.token.txt         sample_data/
# Flickr_8k.devImages.txt     Flickr_8k.trainImages.txt

# %%
from itertools import islice

# %%
def load_captions_data(filename):
    """Loads captions (text) data and maps them to corresponding images.

    Args:
        filename: Path to the text file containing caption data.

    Returns:
        caption_mapping: Dictionary mapping image names and the corresponding captions
        text_data: List containing all the available captions
    """

    with open(filename) as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        for line in caption_data:
            line = line.rstrip("\n")
            # Image name and captions are separated using a tab
            img_name, caption = line.split("\t")

            # Each image is repeated five times for the five different captions.
            # Each image name has a suffix `#(caption_number)`
            img_name = img_name.split("#")[0]
            img_name = os.path.join(IMAGES_PATH, img_name.strip())

            # We will remove caption that are either too short to too long
            tokens = caption.strip().split()
            print("tokens", tokens)

            if len(tokens) < 5 or len(tokens) > SEQ_LENGTH:
                images_to_skip.add(img_name)
                continue

            if img_name.endswith("jpg") and img_name not in images_to_skip:
                # We will add a start and an end token to each caption
                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_name in caption_mapping:
                    caption_mapping[img_name].append(caption)
                else:
                    caption_mapping[img_name] = [caption]

        for img_name in images_to_skip:
            if img_name in caption_mapping:
                del caption_mapping[img_name]

        return caption_mapping, text_data

# %%
# Load the dataset
captions_mapping, text_data = load_captions_data("Flickr8k.token.txt")
# Out:
# Streaming output truncated to the last 5000 lines.
# tokens ['A', 'dog', 'is', 'jumping', 'over', 'a', 'log', 'in', 'a', 'wooded', 'area', 'while', 'carrying', 'another', 'log', '.']
# tokens ['A', 'dog', 'with', 'a', 'stick', 'in', 'his', 'mouth', 'jumps', 'over', 'a', 'fallen', 'tree', 'in', 'the', 'forest', '.']
# tokens ['Dog', 'carries', 'stick', 'and', 'jumps', 'over', 'a', 'log', '.']
# tokens ['The', 'dog', 'carries', 'a', 'stick', 'and', 'jumps', 'over', 'a', 'log', 'in', 'the', 'woods', '.']
# tokens ['The', 'dog', 'jumps', 'over', 'the', 'log', 'with', 'a', 'stick', 'in', 'its', 'mouth', '.']
# tokens ['A', 'black', 'and', 'brown', 'dog', 'is', 'running', 'between', 'two', 'cement', 'barriers', 'with', 'snow', '.']
# tokens ['a', 'dog', 'runs', 'down', 'the', 'cold', 'aisle', '.']
# tokens ['Black', 'and', 'tan', 'small', 'dog', 'walking', 'with', 'perked', 'ears', '.']
# tokens ['The', 'black', 'and', 'brown', 'dog', 'walks', 'toward', 'the', 'camera', ',', 'in', 'an', 'enclosed', ',', 'snowy', 'area', '.']
# tokens ['The', 'brown', 'and', 'black', 'dog', 'is', 'running', 'through', 'a', 'snowy', 'street', '.']
# tokens ['A', 'furry', 'dog', 'is', 'running', 'through', 'a', 'doorway', 'leading', 'to', 'plants', '.']
# tokens ['A', 'furry', ',', 'tan', 'dog', 'is', 'outside', 'on', 'a', 'patio', '.']
# tokens ['A', 'short', ',', 'furry', 'dog', 'stands', 'on', 'a', 'brick', 'floor', 'in', 'front', 'of', 'a', 'group', 'of', 'potted', 'plants', '.']
# tokens ['A', 'very', 'hairy', 'dog', 'is', 'running', 'down', 'a', 'hall', '.']
# tokens ['Flowers', 'are', 'behind', 'the', 'fluffy', 'dog', 'that', 'is', 'coming', 'up', 'the', 'step', '.']
# tokens ['A', 'brown', 'and', 'black', 'dog', 'runs', 'through', 'the', 'leaves', '.']
# tokens ['A', 'brown', 'dog', 'is', 'running', '.']
# tokens ['A', 'brown', 'dog', 'with', 'a', 'red', 'collar', 'jumping', 'across', 'a', 'leafy', 'lawn', '.']
# tokens ['A', 'dog', 'with', 'a', 'brindle-colored', 'coat', 'is', 'running', 'across', 'the', 'yard', '.']
# tokens ['The', 'brown', 'dog', 'is', 'wearing', 'a', 'red', 'collar', '.']
# tokens ['A', 'crowd', 'walks', 'along', 'a', 'sidewalk', 'of', 'a', 'farmers', 'market', '.']
# tokens ['A', 'street', 'market', 'filled', 'with', 'white', 'tents', ',', 'pedestrians', ',', 'and', 'vendors', '.']
# tokens ['A', 'woman', 'looks', 'over', 'a', 'table', 'of', 'organic', 'vegetables', 'at', 'a', 'farmer', "'s", 'market', '.']
# tokens ['Men', 'and', 'women', 'walking', 'on', 'the', 'sidewalk', 'outside', 'a', 'marketplace', '.']
# tokens ['Street', 'with', 'many', 'white', 'tents', 'with', 'display', 'table', 'with', 'people', 'walking', 'nearby', '.']
# tokens ['a', 'fruit', 'stand', 'with', 'a', 'group', 'of', 'people', 'standing', 'around', 'it', '.']
# tokens ['A', 'group', 'of', 'people', 'are', 'standing', 'in', 'Linet', 'at', 'a', 'fruit', 'stand', '.']
# tokens ['A', 'group', 'of', 'people', 'shop', 'for', 'fruit', 'at', 'an', 'urban', 'farmers', 'market', '.']
# tokens ['Many', 'people', 'stand', 'near', 'a', 'fruit', 'vendor', 'on', 'a', 'street', '.']
# tokens ['People', 'shopping', 'at', 'a', 'fruit', 'stand', '.']
# tokens ['A', 'group', 'of', 'people', 'stand', 'at', 'a', 'farmers', 'market', 'on', 'a', 'dreary', 'day', '.']
# tokens ['a', 'white', 'tented', 'fruit', 'stand', 'with', 'several', 'people', 'shopping', 'in', 'it', '.']
# tokens ['People', 'shop', 'for', 'fresh', 'produce', 'at', 'an', 'outdoor', 'market', 'in', 'the', 'city', '.']
# tokens ['People', 'visiting', 'a', 'street', 'market', '.']
# tokens ['Several', 'people', 'shop', 'at', 'an', 'outdoor', 'farmer', "'s", 'market', 'on', 'a', 'cloudy', 'day', '.']
# tokens ['a', 'busy', 'highway', 'scene', 'with', 'a', 'woman', 'crossing', 'a', 'crosswalk', 'on', 'the', 'left']
# tokens ['A', 'lady', 'crosses', 'a', 'busy', 'road', 'on', 'the', 'crosswalk', '.']
# tokens ['A', 'woman', 'crosses', 'a', 'street', 'while', 'traffic', 'lines', 'up', 'in', 'the', 'opposite', 'direction', '.']
# tokens ['Street', 'with', 'traffic', 'with', 'one', 'person', 'in', 'crosswalk', ',', 'two', 'others', 'at', 'corner', 'and', 'one', 'person', 'sitting', 'on', 'ground', '.']
# tokens ['Woman', 'walking', 'in', 'crosswalk', 'near', 'a', 'busy', 'street', '.']
# tokens ['a', 'firetruck', 'fights', 'a', 'fire', '.']
# tokens ['a', 'yellow', 'firetruck', 'is', 'parked', 'next', 'to', 'a', 'fire', 'with', 'a', 'man', 'on', 'a', 'ladder', 'pouring', 'water', 'on', 'it']
# tokens ['Firefighters', 'putting', 'out', 'a', 'big', 'fire', '.']
# tokens ['Fireman', 'fighting', 'a', 'fire', '.']
# tokens ['People', 'putting', 'out', 'a', 'fire', '.']
# tokens ['A', 'black', 'dog', 'is', 'swimming', 'while', 'carrying', 'a', 'tennis']
# tokens ['a', 'black', 'dog', 'swimming', 'in', 'the', 'water', 'with', 'a', 'tennis', 'ball', 'in', 'his', 'mouth']
# tokens ['a', 'black', 'dog', 'swims', 'through', 'the', 'water', 'with', 'a', 'tennis', 'ball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'dog', 'swims', 'in', 'water', 'with', 'a', 'blue', 'and', 'green', 'tennis', 'ball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'dog', 'with', 'a', 'ball', 'in', 'its', 'mouth', 'swims', 'in', 'the', 'water', '.']
# tokens ['A', 'brown', 'dog', 'is', 'chewing', 'on', 'a', 'bone', 'with', 'a', 'stuffed', 'animal', 'underneath', 'it', '.']
# tokens ['a', 'dog', 'chews', 'on', 'a', 'bone', '.']
# tokens ['Big', 'brown', 'dog', 'chews', 'on', 'bone', 'lying', 'down', '.']
# tokens ['Big', 'hairy', 'dog', 'chews', 'on', 'a', 'bone', 'while', 'lying', 'on', 'a', 'furry', 'toy', '.']
# tokens ['Brown', 'dog', 'chews', 'on', 'bone', 'while', 'laying', 'on', 'the', 'rug', '.']
# tokens ['Two', 'small', 'white', 'dogs', 'are', 'in', 'a', 'yard', 'chasing', 'a', 'red', 'ball', '.']
# tokens ['Two', 'small', 'white', 'dogs', 'chasing', 'after', 'a', 'red', 'ball', '.']
# tokens ['Two', 'small', 'white', 'dogs', 'chasing', 'a', 'red', 'ball']
# tokens ['Two', 'West', 'Highland', 'Terriers', 'chase', 'a', 'red', 'ball', '.']
# tokens ['Two', 'white', 'dogs', 'chase', 'after', 'a', 'red', 'ball', 'in', 'a', 'yard', 'in', 'front', 'of', 'a', 'white', 'fence', '.']
# tokens ['Four', 'dogs', 'are', 'being', 'walked', 'by', 'two', 'owners', '.']
# tokens ['Four', 'dogs', 'on', 'leashes', 'walk', 'down', 'a', 'sidewalk', '.']
# tokens ['Four', 'little', 'dogs', 'on', 'leashes', 'take', 'a', 'walk', 'on', 'a', 'wide', 'path', '.']
# tokens ['Four', 'small', 'dogs', 'on', 'leashes', 'walking', 'in', 'a', 'park', '.']
# tokens ['Someone', 'is', 'walking', 'their', 'dogs', '.']
# tokens ['A', 'white', 'dog', 'and', 'two', 'black', 'dogs', 'playing']
# tokens ['A', 'white', 'poodle', 'and', '2', 'black', 'poodles', 'are', 'playing', 'on', 'the', 'grass', '.']
# tokens ['A', 'white', 'poodle', 'and', 'two', 'black', 'poodles', 'are', 'playing', 'in', 'the', 'grass', 'on', 'an', 'autumn', 'day', '.']
# tokens ['A', 'white', 'poodle', 'is', 'climbing', 'over', 'a', 'black', 'poodle', ',', 'who', 'is', 'in', 'turn', 'climbing', 'over', 'another', 'black', 'poodle', '.']
# tokens ['Two', 'black', 'dogs', 'and', 'one', 'white', 'dog', 'interact', '.']
# tokens ['A', 'boy', 'is', 'putting', 'the', 'cone', 'end', 'of', 'a', 'melting', 'ice', 'cream', 'cone', 'in', 'his', 'mouth', '.']
# tokens ['A', 'boy', 'with', 'his', 'eyes', 'closed', 'eats', 'the', 'bottom', 'of', 'an', 'ice', 'cream', 'cone', '.']
# tokens ['A', 'young', 'boy', 'eating', 'ice', 'cream', '.']
# tokens ['A', 'young', 'boy', 'wearing', 'a', 'big', 'watch', 'eats', 'an', 'ice', 'cream', 'cone', '.']
# tokens ['Little', 'boy', 'is', 'eating', 'the', 'rest', 'of', 'the', 'ice', 'cream', 'cone', 'from', 'the', 'bottom', 'up', '.']
# tokens ['a', 'man', 'fishes', 'in', 'the', 'ocean', '.']
# tokens ['A', 'man', 'fly', 'fishes', 'in', 'the', 'ocean', '.']
# tokens ['A', 'man', 'fly', 'fishing', '.']
# tokens ['A', 'man', 'is', 'fishing', 'in', 'knee-high', 'waves', 'of', 'water', '.']
# tokens ['The', 'person', 'is', 'fishing', ',', 'with', 'waves', 'splashing', 'around', 'him', '.']
# tokens ['A', 'brown', 'dog', 'plays', 'with', 'a', 'stick', '.']
# tokens ['A', 'brown', 'dog', 'wearing', 'a', 'key', 'is', 'playing', 'in', 'the', 'dirt', '.']
# tokens ['A', 'lean', 'light', 'brown', 'dog', 'has', 'his', 'head', 'down', 'on', 'the', 'ground', 'playing', 'with', 'a', 'stick', '.']
# tokens ['A', 'tan', 'dog', 'rests', 'his', 'head', 'in', 'the', 'sand', '.']
# tokens ['Two', 'dogs', 'and', 'a', 'person', '.']
# tokens ['Two', 'cyclists', 'atop', 'a', 'hill', 'as', 'seen', 'from', 'below', '.']
# tokens ['two', 'cyclist', 'wearing', 'red', 'shirts', 'going', 'over', 'a', 'red', 'hill']
# tokens ['Two', 'people', 'in', 'red', 'outfits', 'riding', 'their', 'bicycles', 'down', 'a', 'dirt', 'road', '.']
# tokens ['Two', 'people', 'ride', 'their', 'bikes', 'down', 'a', 'dirt', 'road', '.']
# tokens ['Two', 'people', 'riding', 'their', 'bikes', 'on', 'a', 'hill', '.']
# tokens ['A', 'man', 'and', 'a', 'woman', 'are', 'biking', 'on', 'a', 'sunny', 'day', '.']
# tokens ['Man', 'and', 'woman', 'cyclists', 'ride', 'pass', 'signs', 'on', 'rural', 'road', '.']
# tokens ['Two', 'bicyclists', 'ride', 'down', 'a', 'hill', '.']
# tokens ['Two', 'friends', 'bike', 'down', 'a', 'hill', '.']
# tokens ['Two', 'people', 'are', 'riding', 'their', 'bicycles', 'on', 'a', 'dirt', 'road']
# tokens ['A', 'brown', 'dog', 'carries', 'an', 'object', 'in', 'its', 'mouth', 'on', 'a', 'snowy', 'hillside', '.']
# tokens ['A', 'collie', 'running', 'through', 'the', 'snow', '.']
# tokens ['A', 'Sheltie', 'dog', 'carries', 'a', 'white-colored', 'toy', 'in', 'its', 'mouth', 'as', 'it', 'walks', 'across', 'the', 'snow', '.']
# tokens ['Dog', 'with', 'a', 'toy', 'in', 'the', 'snow', '.']
# tokens ['The', 'dog', 'wades', 'through', 'deep', 'snow', 'with', 'something', 'in', 'its', 'mouth', '.']
# tokens ['A', 'black', 'dog', 'in', 'a', 'pink', 'sweater', 'is', 'up', 'on', 'his', 'hind', 'legs', 'in', 'front', 'of', 'a', 'pink', 'blanket', '.']
# tokens ['A', 'dog', 'on', 'two', 'feet', 'wearing', 'a', 'pink', 'sweater', '.']
# tokens ['A', 'dog', 'wears', 'a', 'pink', 'sweater', '.']
# tokens ['a', 'little', 'puppy', 'wearing', 'a', 'pink', 'sweater', ',', 'jumps', '.']
# tokens ['The', 'dog', 'is', 'wearing', 'a', 'pink', 'sweater', '.']
# tokens ['A', 'girl', 'wearing', 'a', 'brown', 'jacket', 'and', 'blue', 'jeans', 'has', 'on', 'some', 'white', 'headphones', 'and', 'is', 'walking', '.']
# tokens ['A', 'girl', 'wearing', 'earphones', 'walks', 'past', 'a', 'traffic', 'cone', '.']
# tokens ['A', 'woman', 'in', 'black', 'and', 'red', 'listens', 'to', 'an', 'Ipod', ',', 'walks', 'down', 'the', 'street']
# tokens ['A', 'woman', 'wearing', 'headphones', 'is', 'walking', 'past', 'a', 'road', 'cone', '.']
# tokens ['A', 'woman', 'wearing', 'headphones', 'walks', 'down', 'the', 'street', '.']
# tokens ['A', 'brown', 'dog', 'playing', 'play', 'wrestling', 'with', 'a', 'black', 'dog', 'on', 'snow', 'covered', 'land', '.']
# tokens ['The', 'two', 'dogs', 'are', 'fighting', 'outside', 'in', 'the', 'snow', '.']
# tokens ['Two', 'brown', 'dogs', 'playing', 'in', 'snow']
# tokens ['two', 'dogs', 'are', 'wrestling', 'in', 'a', 'snow', 'covered', 'field', '.']
# tokens ['Two', 'dogs', 'playing', 'on', 'snow', 'covered', 'ground']
# tokens ['A', 'man', 'crouched', 'in', 'the', 'bare', 'branches', 'of', 'a', 'fallen', 'tree', '.']
# tokens ['A', 'man', 'in', 'a', 'white', 'shirt', 'and', 'khaki', 'pants', 'crouches', 'on', 'a', 'fallen', 'tree', 'trunk', '.']
# tokens ['A', 'man', 'in', 'tan', 'capris', ',', 'brown', 'sandals', ',', 'and', 'a', 'white', 't-shirt', ',', 'crouches', 'on', 'the', 'trunk', 'of', 'a', 'tree', '.']
# tokens ['A', 'man', 'is', 'crouched', 'on', 'top', 'of', 'a', 'horizontal', 'tree', '.']
# tokens ['A', 'man', 'sitting', 'in', 'the', 'middle', 'of', 'branches', 'on', 'a', 'fallen', 'tree', '.']
# tokens ['A', 'black', 'dog', 'carries', 'a', 'huge', 'stick', 'in', 'its', 'mouth', '.']
# tokens ['A', 'black', 'dog', 'is', 'carrying', 'a', 'huge', 'stick', 'whilst', 'walking', 'in', 'the', 'snow', '.']
# tokens ['A', 'dog', 'carries', 'a', 'huge', ',', 'snow', 'covered', 'stick', '.']
# tokens ['A', 'dog', 'carries', 'a', 'very', 'large', 'tree', 'branch', 'in', 'the', 'snow', '.']
# tokens ['The', 'brown', 'and', 'white', 'dog', 'carries', 'a', 'very', 'large', 'stick', 'across', 'the', 'snow', '.']
# tokens ['A', 'black', 'dog', 'and', 'a', 'brown', 'dog', 'are', 'standing', 'next', 'to', 'each', 'other', 'in', 'the', 'snow', '.']
# tokens ['A', 'little', 'tan', 'dog', 'is', 'in', 'confrontation', 'with', 'a', 'large', 'black', 'dog', 'in', 'the', 'snow', '.']
# tokens ['A', 'scruffy', 'golden', 'dog', 'meeting', 'a', 'black', 'Doberman', 'in', 'the', 'snow', '.']
# tokens ['Two', 'dogs', 'in', 'the', 'snow', '.']
# tokens ['Two', 'dogs', 'standing', 'in', 'snow', '.']
# tokens ['A', 'dog', 'walking', 'along', 'the', 'side', 'of', 'a', 'house', 'in', 'the', 'snow', '.']
# tokens ['A', 'white', 'dog', 'is', 'walking', 'by', 'a', 'building', 'in', 'the', 'snow', '.']
# tokens ['A', 'white', 'dog', 'next', 'to', 'a', 'basement', 'window', '.']
# tokens ['a', 'white', 'dog', 'walking', 'on', 'some', 'rocks', 'along', 'a', 'house', 'in', 'the', 'snow', '.']
# tokens ['A', 'white', 'dog', 'walks', 'in', 'the', 'snow']
# tokens ['a', 'brown', 'dog', 'about', 'to', 'jump', 'on', 'a', 'smaller', 'black', 'and', 'tan', 'dog']
# tokens ['Large', 'dog', 'playing', 'with', 'smaller', 'dog']
# tokens ['Two', 'dogs', 'are', 'playing', 'together', 'outside', '.']
# tokens ['Two', 'dogs', 'playing', 'in', 'the', 'grass', 'with', 'an', 'adult', 'nearby', '.']
# tokens ['Two', 'dogs', 'playing', 'with', 'each', 'other', '.']
# tokens ['A', 'black', 'dog', 'runs', 'along', 'a', 'field', 'where', 'black', 'birds', 'are', 'beginning', 'to', 'fly', '.']
# tokens ['A', 'dark', 'colored', 'dog', 'running', 'in', 'a', 'field', 'with', 'multilple', 'birds', 'in', 'the', 'background', '.']
# tokens ['A', 'dog', 'runs', 'at', 'birds', 'taking', 'flight']
# tokens ['A', 'grey', 'dog', 'chases', 'a', 'bunch', 'of', 'crows', ',', 'a', 'river', 'in', 'the', 'background', '.']
# tokens ['The', 'dog', 'chases', 'the', 'birds', 'in', 'the', 'field', '.']
# tokens ['a', 'boy', 'plays', 'with', 'a', 'train', 'set', '.']
# tokens ['A', 'boy', 'takes', 'off', 'his', 'glasses', 'while', 'playing', 'with', 'his', 'toy', 'trains', '.']
# tokens ['A', 'little', 'boy', 'is', 'playing', 'with', 'some', 'trains', '.']
# tokens ['a', 'small', 'child', 'wearing', 'a', 'blue', 'shirt', 'playing', 'with', 'his', 'glasses', '.']
# tokens ['A', 'young', 'boy', 'pulling', 'down', 'his', 'eye', 'glasses', 'and', 'looking', 'a', 'toy', 'trains']
# tokens ['A', 'girl', 'in', 'a', 'white', 'cap', 'eats', 'a', 'slice', 'of', 'fruit', 'next', 'to', 'a', 'girl', 'in', 'a', 'blue', 'cap', 'who', 'is', 'eating', 'chocolate', '.']
# tokens ['One', 'young', 'girl', 'eats', 'fruit', 'while', 'another', 'eats', 'chocolate', '.']
# tokens ['Two', 'children', 'taking', 'in', 'a', 'snack', '.']
# tokens ['Two', 'girls', 'sitting', 'in', 'the', 'grass', 'wearing', 'hats', 'eat', 'snacks', '.']
# tokens ['Two', 'girls', 'with', 'baseball', 'caps', 'are', 'eating', 'a', 'snack', 'outside', '.']
# tokens ['A', 'brown', 'dog', 'is', 'carrying', 'a', 'toy', 'in', 'the', 'snow', '.']
# tokens ['A', 'dog', 'running', 'with', 'something', 'in', 'its', 'mouth']
# tokens ['a', 'dog', 'runs', 'across', 'the', 'snow', '.']
# tokens ['A', 'dog', 'with', 'a', 'frisbie', 'in', 'his', 'mouth', 'is', 'running', 'in', 'a', 'snowy', 'field', '.']
# tokens ['Tan', 'dog', 'with', 'a', 'toy', 'running', 'in', 'the', 'snow', '.']
# tokens ['A', 'black', 'and', 'white', 'dog', 'stands', 'on', 'the', 'grass', 'with', 'a', 'baseball', 'in', 'his', 'mouth']
# tokens ['A', 'closeup', 'of', 'a', 'small', 'black', 'and', 'white', 'dog', 'with', 'a', 'baseball', 'in', 'its', 'mouth', '.']
# tokens ['Black', 'and', 'white', 'dog', 'holding', 'a', 'baseball', 'in', 'mouth', '.']
# tokens ['Brown', 'and', 'white', 'dog', 'with', 'baseball', 'in', 'mouth', ',', 'field', 'and', 'building', '.']
# tokens ['brown', 'and', 'white', 'dog', 'with', 'a', 'baseball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'person', 'peaks', 'their', 'head', 'out', 'of', 'a', 'tent', 'set', 'up', 'in', 'a', 'snowy', 'field', '.']
# tokens ['A', 'woman', 'emerges', 'from', 'her', 'snow', 'covered', 'tent', '.']
# tokens ['a', 'woman', 'sticking', 'her', 'head', 'out', 'of', 'her', 'tent', 'on', 'the', 'side', 'of', 'a', 'snowy', 'moutnain', '.']
# tokens ['A', 'woman', 'wearing', 'glasses', 'and', 'a', 'hat', 'pokes', 'her', 'head', 'through', 'the', 'door', 'of', 'a', 'tent', 'on', 'a', 'snowy', 'day', '.']
# tokens ['The', 'camper', 'opens', 'up', 'to', 'see', 'snow', 'all', 'around', '.']
# tokens ['A', 'hiker', 'moves', 'up', 'a', 'snowy', 'mountain', '.']
# tokens ['A', 'woman', 'in', 'a', 'tank', 'and', 'sunglasses', 'climbs', 'a', 'sunny', 'but', 'snow-covered', 'slope', '.']
# tokens ['A', 'woman', 'wearing', 'a', 'black', 'hat', 'and', 'white', 'sunglasses', 'walks', 'up', 'a', 'snowy', 'and', 'steep', 'path', '.']
# tokens ['A', 'woman', 'wearing', 'short', 'sleeves', 'and', 'sunglasses', 'is', 'backpacking', 'up', 'a', 'snowy', 'mountain', 'cliff', '.']
# tokens ['Woman', 'climbing', 'a', 'snow', 'covered', 'mountain', 'looking', 'at', 'people', 'behind', 'her', '.']
# tokens ['A', 'hiker', 'climbs', 'a', 'mountain', 'on', 'a', 'windy', 'day', '.']
# tokens ['a', 'man', 'walking', 'up', 'a', 'mountain', 'with', 'snow', 'on', 'the', 'surface']
# tokens ['A', 'person', 'hikes', 'across', 'a', 'grass', 'and', 'snow', 'covered', 'plain']
# tokens ['Person', 'walking', 'across', 'a', 'snow', 'covered', 'mountain', '.']
# tokens ['The', 'man', 'carries', 'a', 'large', 'backpack', 'while', 'hiking', 'through', 'snow-covered', 'terrain', '.']
# tokens ['A', 'girl', 'treks', 'through', 'the', 'snow', 'with', 'her', 'backpack', 'on', '.']
# tokens ['A', 'hiker', 'is', 'climbing', 'up', 'a', 'snowy', 'mountain', '.']
# tokens ['A', 'hiker', 'using', 'hiking', 'poles', 'on', 'a', 'snowy', 'mountain', '.']
# tokens ['Someone', 'hikes', 'through', 'a', 'snowy', 'mountain', 'range']
# tokens ['The', 'woman', 'is', 'hiking', 'up', 'a', 'snowy', 'hill', '.']
# tokens ['A', 'man', 'gesticulates', '.']
# tokens ['A', 'man', 'in', 'a', 'white', 'shirt', 'holding', 'both', 'hands', 'out', '.']
# tokens ['An', 'elderly', 'male', 'wearing', 'a', 'white', 'Wal', 'Mart', 'smock', 'with', 'his', 'arms', 'and', 'hand', 'extended', 'in', 'front', 'of', 'him', '.']
# tokens ['A', 'old', 'man', 'in', 'a', 'Wall', 'Mart', 'unifrom', 'holds', 'his', 'arms', 'out', 'to', 'the', 'camera', '.']
# tokens ['a', 'walmart', 'worker', 'wearing', 'a', 'white', 'coat', '.']
# tokens ['A', 'brown', 'and', 'white', 'dog', 'is', 'standing', 'on', 'its', 'hind', 'legs', 'reaching', 'for', 'a', 'ball', '.']
# tokens ['A', 'dog', 'jumps', 'to', 'meet', 'a', 'soccer', 'ball', 'flying', 'towards', 'it', '.']
# tokens ['A', 'dog', 'stands', 'on', 'one', 'leg', 'and', 'tries', 'to', 'get', 'a', 'soccer', 'ball', '.']
# tokens ['Black', 'and', 'white', 'dog', 'jumps', 'for', 'ball', '.']
# tokens ['The', 'brown', 'and', 'white', 'dog', 'is', 'jumping', 'up', 'in', 'an', 'attempt', 'to', 'catch', 'a', 'ball', '.']
# tokens ['A', 'guy', 'on', 'inline', 'skates', 'with', 'a', 'white', 'hat', 'is', 'on', 'a', 'yellow', 'rail', '.']
# tokens ['a', 'male', 'skater', 'is', 'riding', 'a', 'yellow', 'rail']
# tokens ['A', 'man', 'Rollerblades', 'across', 'a', 'yellow', 'pole', 'at', 'night', '.']
# tokens ['An', 'inline', 'skater', 'boy', 'balances', 'on', 'a', 'yellow', 'rail', '.']
# tokens ['A', 'skater', 'does', 'a', 'trick', 'on', 'a', 'yellow', 'handrail', '.']
# tokens ['A', 'dog', 'jumping', 'up', 'to', 'touch', 'a', 'woman', "'s", 'hand', '.']
# tokens ['a', 'dog', 'jumps', 'to', 'an', 'elderly', 'woman', '.']
# tokens ['An', 'airborne', 'dog', 'on', 'a', 'leash', 'with', 'a', 'woman', '.']
# tokens ['The', 'small', 'dog', 'is', 'leaping', 'in', 'the', 'air', 'toward', 'the', 'woman', "'s", 'hand', '.']
# tokens ['The', 'woman', 'in', 'the', 'blue', 'sweater', 'encourages', 'the', 'dog', 'to', 'jump', 'in', 'the', 'air', '.']
# tokens ['a', 'black', 'dog', 'digging', 'through', 'the', 'snow', '.']
# tokens ['A', 'black', 'dog', 'digs', 'in', 'the', 'snow', '.']
# tokens ['A', 'large', 'black', 'dog', 'is', 'digging', 'in', 'the', 'deep', 'snow', '.']
# tokens ['A', 'small', 'black', 'and', 'brown', 'dog', 'is', 'standing', 'in', 'the', 'snow', '.']
# tokens ['Black', 'dog', 'digging', 'in', 'white', 'snow', '.']
# tokens ['two', 'big', 'brown', 'dogs', 'running', 'through', 'the', 'snow', '.']
# tokens ['Two', 'brown', 'dogs', 'are', 'running', 'over', 'snow', 'in', 'a', 'line', '.']
# tokens ['Two', 'brown', 'dogs', 'walking', 'through', 'snow', '.']
# tokens ['two', 'dogs', 'running', 'in', 'the', 'snow']
# tokens ['Two', 'weimaraners', 'running', 'in', 'the', 'snow', '.']
# tokens ['a', 'boy', 'in', 'a', 'blue', 'shirt', 'is', 'walking', 'along', 'a', 'tan', 'and', 'blue', 'wall']
# tokens ['A', 'boy', 'in', 'stripes', 'walking', 'along', 'a', 'ledge', '.']
# tokens ['a', 'boy', 'scales', 'the', 'wall', '.']
# tokens ['A', 'child', 'in', 'a', 'striped', 'shirt', 'is', 'walking', 'along', 'a', 'wall', '.']
# tokens ['Boy', 'in', 'striped', 't-shirt', 'walking', 'along', 'a', 'ledge', '.']
# tokens ['A', 'black', 'and', 'white', 'dog', ',', 'with', 'a', 'red', 'cap', 'on', 'its', 'head', ',', 'yawning', '.']
# tokens ['A', 'dog', 'that', 'is', 'wearing', 'a', 'red', 'cap', 'is', 'standing', 'by', 'a', 'guitar', 'with', 'its', 'mouth', 'wide', 'open', '.']
# tokens ['A', 'dog', 'wearing', 'a', 'hat', 'stretches', 'open', 'its', 'mouth', '.']
# tokens ['A', 'dog', 'wearing', 'a', 'red', 'hat', 'opens', 'its', 'mouth', 'wide', '.']
# tokens ['The', 'dog', 'is', 'wearing', 'a', 'red', 'baseball', 'cap', ',', 'and', 'has', 'its', 'mouth', 'wide', 'open', '.']
# tokens ['A', 'large', 'black', 'dog', 'and', 'a', 'small', 'brown', 'dog', 'are', 'playing', 'in', 'the', 'house', '.']
# tokens ['A', 'large', 'black', 'dog', 'has', 'his', 'paw', 'on', 'a', 'small', 'brown', 'dog', '.']
# tokens ['A', 'large', 'black', 'dog', 'relaxes', 'while', 'a', 'small', 'brown', 'dog', 'investigates', 'nearby', 'a', 'doorway', '.']
# tokens ['two', 'dogs', 'play', 'together', '.']
# tokens ['Two', 'dogs', 'tussling', 'on', 'a', 'dog', 'bed', ',', 'with', 'a', 'french', 'door', 'and', 'a', 'Persian', 'rug', 'in', 'the', 'background', '.']
# tokens ['A', 'black', 'lab', 'is', 'running', 'in', 'a', 'race', '.']
# tokens ['A', 'shiny', 'black', 'dog', 'runs', 'on', 'the', 'grass', 'during', 'a', 'bright', 'and', 'sunny', 'day', '.']
# tokens ['The', 'big', ',', 'black', ',', 'running', 'dog', 'is', 'wearing', 'a', 'strap', 'around', 'its', 'chest', '.']
# tokens ['The', 'black', 'dog', 'is', 'running', 'through', 'the', 'clearing', '.']
# tokens ['The', 'large', 'black', 'dog', 'is', 'running', 'through', 'a', 'grassy', 'area', '.']
# tokens ['A', 'woman', 'at', 'an', 'outdoor', 'food', 'stand', '.']
# tokens ['A', 'woman', 'makes', 'a', 'purchase', 'at', 'an', 'outdoor', 'vendor', '.']
# tokens ['The', 'woman', 'in', 'the', 'red', 'jacket', 'looks', 'as', 'if', 'she', 'was', 'buying', 'something', 'from', 'the', 'open', 'air', 'vendor', '.']
# tokens ['The', 'woman', 'is', 'purchasing', 'a', 'product']
# tokens ['Woman', 'in', 'red', 'coat', 'buying', 'something', 'from', 'a', 'street', 'vendor', '.']
# tokens ['A', 'firefighter', 'preparing', 'to', 'put', 'a', 'car', 'fire', 'out', '.']
# tokens ['A', 'firefighter', 'responding', 'to', 'a', 'car', 'fire', '.']
# tokens ['A', 'fireman', 'pulling', 'out', 'a', 'firehose', 'next', 'to', 'a', 'blue', 'car', 'engulfed', 'in', 'flames', '.']
# tokens ['The', 'firefighter', 'has', 'a', 'hose', 'ready', 'to', 'tackle', 'a', 'car', 'fire', '.']
# tokens ['The', 'fireman', 'is', 'pulling', 'the', 'hose', 'to', 'a', 'car', 'fire', '.']
# tokens ['A', 'couple', 'shopping', 'for', 'plants', 'and', 'flowers', '.']
# tokens ['Man', 'in', 'brown', 'jacket', 'with', 'his', 'arm', 'around', 'person', 'in', 'black', 'jacket', 'at', 'flower', 'shop']
# tokens ['People', 'are', 'waiting', 'outside', 'a', 'lawn', 'and', 'garden', 'seller', '.']
# tokens ['The', 'man', 'has', 'his', 'arm', 'around', 'the', 'woman', 'in', 'a', 'flower', 'market', '.']
# tokens ['The', 'man', 'has', 'his', 'arm', 'on', 'the', 'woman', 'as', 'they', 'shop', 'in', 'an', 'outdoor', 'market', '.']
# tokens ['a', 'dog', 'on', 'a', 'leash', 'jumps', 'over', 'a', 'stone', 'wall', '.']
# tokens ['A', 'dog', 'on', 'a', 'leash', 'tries', 'to', 'get', 'over', 'a', 'rock', 'wall', '.']
# tokens ['A', 'dog', 'owner', 'watches', 'their', 'dog', 'climb', 'over', 'the', 'rocky', 'outline', 'of', 'a', 'walking', 'path', '.']
# tokens ['Dog', 'on', 'a', 'red', 'leash', 'with', 'a', 'woman', '.']
# tokens ['Grey', 'and', 'white', 'dog', 'with', 'red', 'harness', 'and', 'leash', 'going', 'over', 'a', 'stone', 'wall', '.']
# tokens ['A', 'Chinese', 'Dragon', 'at', 'a']
# tokens ['A', 'man', 'stands', 'between', 'two', 'flags', 'and', 'behind', 'another', 'man', 'carrying', 'a', 'dragon', 'mask', '.']
# tokens ['An', 'Asian', 'man', 'is', 'carrying', 'a', 'green', 'flag', 'whilst', 'leading', 'a', 'carnival', 'dragon', 'in', 'a', 'parade', '.']
# tokens ['An', 'elderly', 'Asian', 'man', 'is', 'bearing', 'a', 'green', 'flag', 'in', 'a', 'dragon', 'parade', '.']
# tokens ['Asian', 'woman', 'holding', 'flag', 'with', 'costume', 'dragon', 'in', 'the', 'background']
# tokens ['A', 'group', 'of', 'teenage', 'boys', 'on', 'a', 'road', 'jumping', 'joyfully', '.']
# tokens ['Four', 'boys', 'running', 'and', 'jumping', '.']
# tokens ['Four', 'kids', 'jumping', 'on', 'the', 'street', 'with', 'a', 'blue', 'car', 'in', 'the', 'back', '.']
# tokens ['Four', 'young', 'men', 'are', 'running', 'on', 'a', 'street', 'and', 'jumping', 'for', 'joy', '.']
# tokens ['sveral', 'young', 'man', 'jumping', 'down', 'the', 'street']
# tokens ['A', 'golden', 'retriever', 'on', 'a', 'leash', 'moves', 'through', 'snow', '.']
# tokens ['A', 'large', 'golden', 'retriever', 'on', 'a', 'leash', 'standing', 'in', 'the', 'snow', '.']
# tokens ['A', 'tan', 'dog', 'on', 'a', 'leash', 'walks', 'in', 'the', 'snow', '.']
# tokens ['Tan', 'dog', 'on', 'lead', 'standing', 'on', 'surface', 'covered', 'with', 'white', 'snow', '.']
# tokens ['The', 'small', 'dog', 'on', 'the', 'leash', 'is', 'walking', 'through', 'the', 'snow', '.']
# tokens ['a', 'man', 'stands', 'alone', 'on', 'the', 'rocks', '.']
# tokens ['A', 'man', 'stands', 'on', 'a', 'rocky', 'cliff', 'overlooking', 'a', 'body', 'of', 'water', '.']
# tokens ['A', 'person', 'is', 'standing', 'on', 'jagged', 'rocks', 'above', 'the', 'water', 'below', '.']
# tokens ['A', 'person', 'with', 'a', 'backpack', 'stands', 'on', 'a', 'rocky', 'bank', 'beside', 'a', 'body', 'of', 'water', '.']
# tokens ['Person', 'standing', 'on', 'rocky', 'edge', 'of', 'water', 'with', 'hilly', 'land', 'in', 'background', '.']
# tokens ['A', 'black', 'and', 'white', 'dog', 'is', 'running', 'through', 'the', 'sand', 'on', 'a', 'beach', '.']
# tokens ['A', 'brown', 'dog', 'with', 'white', 'paws', 'running', 'on', 'the', 'beach', '.']
# tokens ['There', 'are', 'two', 'dogs', 'running', 'on', 'the', 'beach', 'outside', '.']
# tokens ['Two', 'dogs', 'are', 'playing', 'on', 'the', 'beach', 'together', '.']
# tokens ['Two', 'dogs', 'run', 'along', 'a', 'beach', '.']
# tokens ['A', 'man', 'in', 'a', 'blue', 'jacket', 'widely', 'opens', 'his', 'big', 'blue', 'eyes', 'as', 'a', 'man', 'behind', 'him', 'closes', 'his', 'eyes', 'as', 'he', 'covers', 'his', 'mouth', '.']
# tokens ['A', 'man', 'wearing', 'a', 'blue', 'jacket', 'looks', 'at', 'the', 'camera', '.']
# tokens ['A', 'startled', 'man', 'wearing', 'a', 'blue', 'jacket', 'is', 'looking', 'at', 'the', 'camera', '.']
# tokens ['A', 'wide', 'eyed', 'guy', 'in', 'a', 'blue', 'jacket', 'is', 'holding', 'a', 'beer', 'and', 'standing', 'next', 'to', 'a', 'guy', 'holding', 'his', 'nose', '.']
# tokens ['Man', 'in', 'blue', 'is', 'posing', 'for', 'the', 'camera', '.']
# tokens ['A', 'girl', 'is', 'standing', 'and', 'another', 'one', 'is', 'sitting', 'by', 'a', 'tree']
# tokens ['One', 'girl', 'sitting', 'down', 'reading', 'and', 'another', 'girl', 'standing', 'in', 'front', 'of', 'her', '.']
# tokens ['one', 'girl', 'sitting', 'on', 'a', 'nech', 'near', 'a', 'tree', 'while', 'another', 'stands', 'next', 'to', 'her', 'on', 'the', 'sidewalk', '.']
# tokens ['Two', 'people', 'on', 'a', 'street', ';', 'one', 'sitting', 'on', 'the', 'planter', 'surrounding', 'a', 'tree', '.']
# tokens ['Two', 'women', ',', 'one', 'sitting', 'and', 'one', 'standing', ',', 'near', 'a', 'tree', '.']
# tokens ['A', 'man', 'walking', 'a', 'small', 'white', 'and', 'a', 'big', 'white', 'dog', 'on', 'leashes', '.']
# tokens ['A', 'man', 'walking', 'down', 'a', 'sidewalk', 'with', '2', 'dogs', 'on', 'leashes', '.']
# tokens ['A', 'man', 'walking', 'two', 'dogs', 'down', 'a', 'street', '.']
# tokens ['A', 'man', 'walks', 'two', 'dogs', 'in', 'the', 'city', '.']
# tokens ['a', 'man', 'walks', 'two', 'dogs', 'on', 'leashes', 'down', 'the', 'street']
# tokens ['The', 'back', 'of', 'two', 'men', "'s", 'heads', 'riding', 'on', 'a', 'train', '.']
# tokens ['The', 'backs', 'of', 'the', 'heads', 'of', 'two', 'men', 'that', 'are', 'plugging', 'their', 'ears', 'while', 'riding', 'the', 'subway', '.']
# tokens ['Two', 'guys', 'are', 'sharing', 'headphones', 'and', 'are', 'listening', 'to', 'music', 'on', 'a', 'subway', '.']
# tokens ['Two', 'men', 'on', 'a', 'busy', 'subway', ',', 'seen', 'from', 'behind', ',']
# tokens ['Two', 'people', 'sitting', 'together', 'on', 'a', 'subway', 'listening', 'to', 'earphones', '.']
# tokens ['A', 'man', 'attached', 'to', 'strings', 'is', 'watched', 'by', 'a', 'crowd', '.']
# tokens ['A', 'man', 'stands', 'below', 'a', 'crowd', '.']
# tokens ['People', 'on', 'a', 'cruise', 'ship', 'deck', ',', 'and', 'overlooking', 'the', 'deck', '.']
# tokens ['People', 'stand', 'on', 'the', 'balcony', 'and', 'deck', 'of', 'a', 'boat', '.']
# tokens ['The', 'people', 'on', 'the', 'balcony', 'are', 'controlling', 'the', 'man', 'in', 'the', 'white', 'shorts', 'like', 'a', 'puppet', '.']
# tokens ['A', 'dog', "'s", 'mouth', 'opens', 'to', 'expose', 'its', 'sharp', 'teeth', '.']
# tokens ['a', 'dog', 'tries', 'to', 'bite', 'another', 'dog', '.']
# tokens ['two', 'black', 'and', 'white', 'dogs', 'fighting', 'with', 'each', 'other']
# tokens ['Two', 'dogs', 'play', 'on', 'the', 'wooden', 'floor', 'inside', '.']
# tokens ['Two', 'dogs', 'play', 'with', 'each', 'other', 'on', 'a', 'wood', 'floor', '.']
# tokens ['A', 'bald', 'man', 'stands', 'in', 'a', 'snowy', 'side', 'street', '.']
# tokens ['A', 'bald', 'man', 'wearing', 'a', 'jacket', 'looks', 'at', 'icy', 'sidewalk', '.']
# tokens ['A', 'man', 'is', 'standing', 'on', 'an', 'icy', 'street', 'with', 'a', 'building', 'beside', 'him', '.']
# tokens ['A', 'man', 'wearing', 'a', 'gray', 'coat', 'looks', 'to', 'the', 'right', 'on', 'a', 'snowy', 'street', '.']
# tokens ['a', 'man', 'wearing', 'a', 'grey', 'jacket', 'standing', 'on', 'the', 'side', 'of', 'a', 'street', '.']
# tokens ['A', 'small', 'white', 'dog', 'jumping', 'to', 'catch', 'a', 'tennis', 'ball', '.']
# tokens ['A', 'small', 'white', 'dog', 'stands', 'on', 'one', 'leg', 'to', 'catch', 'a', 'ball', '.']
# tokens ['A', 'white', 'dog', 'is', 'in', 'the', 'air', 'with', 'a', 'ball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'white', 'dog', 'is', 'leaping', 'into', 'the', 'air', 'to', 'catch', 'a', 'ball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'white', 'dog', 'with', 'a', 'black', 'collar', 'jumps', 'up', 'to', 'catch', 'a', 'tennis', 'ball']
# tokens ['One', 'child', 'reaches', 'up', 'for', 'something', 'while', 'another', 'stands', 'beside', 'him', '.']
# tokens ['One', 'child', 'with', 'a', 'colourful', 'toy', 'and', 'another', 'child', 'reaching', 'up', '.']
# tokens ['Two', 'babies', 'in', 'sweaters', 'playing', 'with', 'a', 'toy', '.']
# tokens ['Two', 'children', 'have', 'expressions', 'of', 'happiness', 'as', 'they', 'reach', 'for', 'something', 'out', 'of', 'sight', '.']
# tokens ['Two', 'kids', 'playing', 'on', 'a', 'street']
# tokens ['A', 'military', 'man', 'says', 'hello', 'to', 'a', 'group', 'of', 'children', 'waving', 'American', 'flags', '.']
# tokens ['a', 'veteran', 'in', 'a', 'brown', 'uniform', 'at', 'a', 'parade', 'with', 'children', 'and', 'American', 'flags']
# tokens ['Military', 'official', 'greets', 'children', 'who', 'are', 'waving', 'American', 'flags', '.']
# tokens ['The', 'man', 'in', 'the', 'military', 'uniform', 'greets', 'children', 'waving', 'American', 'flags', '.']
# tokens ['Young', 'children', 'waving', 'American', 'flags', 'for', 'a', 'soldier']
# tokens ['A', 'black', 'dachshund', 'sniffs', 'another', 'dog', 'wearing', 'a', 'striped', 'shirt', '.']
# tokens ['A', 'dog', 'wearing', 'a', 'striped', 'sweater', 'touches', 'noses', 'with', 'another', 'dog', '.']
# tokens ['A', 'white', 'dog', 'wearing', 'a', 'zepra', 'print', 'shirt', 'is', 'nose', 'to', 'nose', 'with', 'a', 'black', 'dog', 'wearing', 'a', 'pink', 'collar', '.']
# tokens ['A', 'white', 'dog', 'with', 'a', 'sweater', 'on', 'and', 'a', 'black', 'and', 'brown', 'dog', 'touching', 'noses', '.']
# tokens ['Two', 'dogs', 'meeting', 'nose', 'to', 'nose', '.']
# tokens ['A', 'brown', 'dog', 'and', 'a', 'gray', 'dog', 'are', 'playing', 'in', 'the', 'snow', '.']
# tokens ['Dogs', 'play', 'in', 'the', 'snow', '.']
# tokens ['Two', 'dogs', 'are', 'wrestling', 'on', 'the', 'ground', 'in', 'the', 'snow', '.']
# tokens ['Two', 'dogs', 'playing', 'in', 'the', 'snow', '.']
# tokens ['Two', 'dogs', 'play', 'in', 'the', 'snow', '.']
# tokens ['A', 'brown', 'dog', 'carries', 'something', 'in', 'his', 'mouth', 'while', 'walking', 'through', 'snow', '.']
# tokens ['A', 'dark-colored', 'dog', 'walking', 'across', 'snow', 'with', 'something', 'in', 'its', 'mouth', '.']
# tokens ['A', 'dog', 'carries', 'an', 'object', 'in', 'the', 'snow', '.']
# tokens ['A', 'dog', 'walks', 'through', 'the', 'snow', 'while', 'blindfolded', 'carrying', 'something', 'in', 'his', 'mouth', '.']
# tokens ['The', 'brown', 'dog', 'has', 'an', 'object', 'in', 'his', 'mouth', '.']
# tokens ['A', 'man', 'is', 'shoveling', 'snow', 'during', 'a', 'sunrise', '.']
# tokens ['A', 'man', 'stands', 'in', 'the', 'snow', 'as', 'the', 'sun', 'sets', '.']
# tokens ['A', 'mist', 'overshadows', 'a', 'man', 'in', 'winter', 'gear', 'and', 'the', 'winter', 'landscape', 'in', 'front', 'of', 'him', '.']
# tokens ['A', 'person', 'stands', 'in', 'a', 'snowy', 'area', 'looking', 'down', '.']
# tokens ['Man', 'walking', 'through', 'the', 'deep', 'snow', 'at', 'dusk', '.']
# tokens ['A', 'black', 'and', 'gray', 'dog']
# tokens ['two', 'black', 'dogs', 'fight', '.']
# tokens ['two', 'black', 'poodles', 'fighting', '.']
# tokens ['Two', 'black', 'poodles', 'playfully', 'tussle', 'on', 'a', 'grassy', ',', 'manicured', 'lawn', '.']
# tokens ['Two', 'small', 'black', 'dogs', 'facing', 'each', 'other', 'with', 'their', 'mouths', 'open', '.']
# tokens ['A', 'big', 'dog', 'is', 'running', 'in', 'the', 'grassy', 'field', 'with', 'woods', 'behind', 'him', '.']
# tokens ['a', 'dog', 'runs', 'across', 'the', 'land', '.']
# tokens ['A', 'German', 'Shepherd', 'jumping', 'in', 'midair', '.']
# tokens ['A', 'German', 'shepherd', 'leaps', 'in', 'midair', '.']
# tokens ['Black', 'and', 'brown', 'dog', 'runs', 'through', 'field', '.']
# tokens ['A', 'dog', 'is', 'about', 'to', 'get', 'a', 'ball', 'that', 'is', 'on', 'orange', 'carpet', '.']
# tokens ['A', 'dog', 'on', 'wood', 'floor', 'is', 'staring', 'at', 'a', 'yellow', 'ball', 'that', 'is', 'lying', 'on', 'orange', 'carpet', '.']
# tokens ['A', 'little', 'brown', 'dog', 'stares', 'at', 'a', 'tennis', 'ball', 'on', 'an', 'orange', 'carpet', '.']
# tokens ['Puppy', 'playing', 'with', 'a', 'tennis', 'ball', 'on', 'an', 'orange', 'rug', '.']
# tokens ['The', 'dog', 'crouched', 'on', 'the', 'orange', 'rug', 'and', 'stared', 'at', 'the', 'tennis', 'ball', '.']
# tokens ['A', 'man', 'in', 'a', 'cap', 'with', 'a', 'goatee', 'leans', 'against', 'the', 'window', 'and', 'reads', 'a', 'magazine', '.']
# tokens ['A', 'man', 'sitting', 'on', 'an', 'empty', 'train']
# tokens ['A', 'man', 'with', 'a', 'black', 'hat', 'and', 'black', 'beard', 'is', 'reading', 'a', 'magazine', 'sitting', 'on', 'a', 'blue', 'bench', '.']
# tokens ['A', 'man', 'with', 'a', 'hat', 'sits', 'in', 'a', 'booth', 'and', 'reads', '.']
# tokens ['The', 'man', 'reading', 'a', 'magazine', 'is', 'sitting', 'in', 'the', 'large', 'room', '.']
# tokens ['A', 'person', 'in', 'uniform', 'is', 'standing', 'in', 'front', 'of', 'a', 'toll', 'bridge', '.']
# tokens ['A', 'woman', 'in', 'a', 'bright', 'safety', 'jacket', 'is', 'standing', 'next', 'to', 'large', 'pipes', '.']
# tokens ['A', 'woman', 'wearing', 'a', 'fluorecent', 'safety', 'jacket', 'stands', 'near', 'equipment', '.']
# tokens ['a', 'woman', 'wearing', 'a', 'neon', 'jacket', 'standing', 'next', 'to', 'a', 'large', 'machine', '.']
# tokens ['The', 'woman', 'is', 'wearing', 'a', 'yellow', 'jacket', 'and', 'blue', 'pants', '.']
# tokens ['A', 'black', 'and', 'white', 'dog', 'is', 'leaping', 'from', 'a', 'snowy', 'path', '.']
# tokens ['A', 'brown', 'and', 'white', 'dog', 'jumps', 'in', 'the', 'air', 'to', 'catch', 'a', 'snowball', '.']
# tokens ['A', 'dog', 'jumps', 'up', 'and', 'tries', 'to', 'catch', 'a', 'lump', 'of', 'snow', '.']
# tokens ['Dog', 'jumping', 'to', 'catch', 'falling', 'snow', 'out', 'in', 'the', 'woods', '.']
# tokens ['The', 'white', 'and', 'brown', 'dog', 'leaps', 'into', 'the', 'air', ',', 'above', 'snow', 'covered', 'ground', '.']
# tokens ['An', 'asian', 'lady', 'in', 'a', 'red', 'jacket', 'taking', 'a', 'photo']
# tokens ['An', 'Asian', 'woman', 'is', 'taking', 'a', 'photograph', 'outside', 'a', 'white', 'columned', 'building', '.']
# tokens ['An', 'older', 'dark', 'haired', 'woman', 'is', 'taking', 'a', 'picture']
# tokens ['A', 'woman', 'in', 'a', 'red', 'coat', 'takes', 'a', 'picture', 'near', 'marble', 'columns', 'at', 'twilight', '.']
# tokens ['A', 'woman', 'wearing', 'a', 'red', 'coat', 'begins', 'to', 'take', 'a', 'picture', '.']
# tokens ['A', 'group', 'of', 'young', 'boys', 'fight', 'over', 'a', 'bag', 'of', 'trash', '.']
# tokens ['Three', 'boys', 'are', 'struggling', 'with', 'one', 'another', 'and', 'reaching', 'for', 'bag', 'of', 'litter', '.']
# tokens ['Three', 'boys', 'standing', 'in', 'a', 'yard', 'with', 'a', 'bunch', 'of', 'paper', '.']
# tokens ['Three', 'people', 'are', 'outside', 'with', 'something', 'on', 'the', 'grass', '.']
# tokens ['Two', 'boys', ',', 'surrounded', 'by', 'paper', 'pieces', ',', 'hold', 'a', 'third', 'boys', 'shirt', 'to', 'prevent', 'him', 'from', 'grabbing', 'a', 'bag', '.']
# tokens ['A', 'lady', 'standing', 'outside', 'a', 'street', 'with', 'a', 'red', 'purse', 'and', 'scarf', 'on', '.']
# tokens ['A', 'person', 'dressed', 'in', 'red', 'and', 'black', 'outside', 'a', 'cracked', 'wall', '.']
# tokens ['A', 'woman', 'is', 'walking', 'with', 'a', 'red', 'bag', '.']
# tokens ['A', 'woman', 'standing', 'by', 'a', 'car', 'in', 'a', 'garage', 'dressed', 'for', 'winter', 'weather', 'in', 'a', 'red', 'knit', 'scarf', ',', 'black', 'gloves', 'and', 'hat', 'and', 'red', 'handbag', '.']
# tokens ['The', 'woman', 'wears', 'a', 'blue', 'coat', ',', 'black', 'hat', ',', 'and', 'red', 'scarf', ',', 'while', 'holding', 'a', 'red', 'bag', '.']
# tokens ['animals', 'in', 'the', 'snow']
# tokens ['Two', 'black', 'and', 'tan', 'dogs', 'are', 'fighting', 'in', 'snow', '.']
# tokens ['Two', 'dogs', 'are', 'laying', 'in', 'the', 'snow', 'with', 'their', 'mouths', 'open', '.']
# tokens ['Two', 'dogs', 'try', 'to', 'bite', 'each', 'other', 'while', 'laying', 'in', 'the', 'snow', '.']
# tokens ['Two', 'dogs', 'wrestle', 'in', 'the', 'snow', '.']
# tokens ['A', 'man', 'in', 'a', 'blue', 'cowboy', 'hat', 'is', 'riding', 'a', 'white', 'horse', '.']
# tokens ['A', 'man', 'in', 'blue', 'is', 'riding', 'a', 'horse', 'on', 'a', 'dirt', 'road', '.']
# tokens ['A', 'man', 'wearing', 'a', 'blue', 'hat', 'and', 'shirt', 'is', 'riding', 'a', 'white', 'horse', '.']
# tokens ['A', 'person', 'in', 'a', 'blue', 'cowboy', 'hat', 'rides', 'a', 'horse', 'down', 'a', 'dirt', 'trail', '.']
# tokens ['The', 'person', 'in', 'the', 'blue', 'shirt', 'and', 'blue', 'hat', 'is', 'riding', 'a', 'white', 'horse', '.']
# tokens ['a', 'man', 'climbs', 'a', 'mountain', '.']
# tokens ['A', 'man', 'climbs', 'the', 'side', 'of', 'a', 'mountain', '.']
# tokens ['A', 'shirtless', 'man', 'climbs', 'a', 'wall', 'in', 'nature', '.']
# tokens ['One', 'man', 'is', 'climbing', 'a', 'rock', 'wall', ',', 'while', 'another', 'man', ',', 'below', ',', 'holds', 'a', 'rope', '.']
# tokens ['two', 'men', 'climbing', 'a', 'mountain']
# tokens ['A', 'rock', 'climber', '.']
# tokens ['There', 'are', 'two', 'people', 'rock', 'climbing', ',', 'one', 'is', 'on', 'the', 'ground', 'while', 'the', 'other', 'climbs', '.']
# tokens ['two', 'men', 'climb', 'a', 'large', 'rock', '.']
# tokens ['Two', 'people', 'rock', 'climbing', '.']
# tokens ['Two', 'rock', 'climbers', 'scaling', 'a', 'sheer', 'cliff', '.']
# tokens ['A', 'blond', 'climber', 'with', 'a', 'white', 'shirt', 'is', 'scaling', 'a', 'stone', 'cliff', '.']
# tokens ['a', 'lone', 'man', 'climbing', 'the', 'side', 'of', 'a', 'large', 'rock', 'wall', '.']
# tokens ['A', 'person', 'climbing', 'a', 'rock', 'face', '.']
# tokens ['a', 'rock', 'climber']
# tokens ['A', 'young', 'man', 'is', 'climbing', 'up', 'a', 'rock', 'face', 'with', 'one', 'rope', 'dangling', 'down', '.']
# tokens ['A', 'man', 'in', 'a', 'lime', 'green', 'vest', 'directs', 'traffic']
# tokens ['A', 'policeman', 'wearing', 'a', 'green', 'vest', 'blows', 'his', 'whistle', 'and', 'moves', 'his', 'arms', '.']
# tokens ['A', 'policeman', 'wearing', 'a', 'neon', 'green', 'vest', 'has', 'a', 'whistle', 'in', 'his', 'mouth', 'while', 'directing', 'traffic', '.']
# tokens ['A', 'police', 'officer', 'in', 'a', 'yellow', 'vest', 'directs', 'traffic', '.']
# tokens ['A', 'traffic', 'director', 'wears', 'a', 'yellow', 'safety', 'suit', 'marked', ',', '"', 'Seattle', 'Police', '.', '"']
# tokens ['A', 'construction', 'worker', 'drills', 'a', 'hole', 'into', 'the', 'ground', '.']
# tokens ['A', 'man', 'wearing', 'a', 'hi-viz', 'jacket', 'is', 'drilling', 'into', 'the', 'road', '.']
# tokens ['A', 'man', 'wearing', 'a', 'yellow', 'vest', 'works', 'in', 'the', 'street', '.']
# tokens ['The', 'construction', 'worker', 'is', 'drilling', 'into', 'the', 'street', 'near', 'a', 'street', 'with', 'active', 'traffic', '.']
# tokens ['The', 'man', 'in', 'the', 'construction', 'gear', 'uses', 'a', 'large', ',', 'red', 'drill', '.']
# tokens ['A', 'hiker', 'on', 'a', 'snow-covered', 'mountain', 'overlooking', 'a', 'valley', '.']
# tokens ['A', 'man', 'carrying', 'a', 'backpack', 'stands', 'on', 'a', 'snowy', 'area', '.']
# tokens ['A', 'man', 'in', 'snow', 'clothes', 'and', 'a', 'red', 'helmet', 'is', 'on', 'top', 'of', 'a', 'mountain', 'with', 'other', 'mountains', 'in', 'the', 'background', '.']
# tokens ['a', 'man', 'wearing', 'a', 'huge', 'backpack', 'and', 'blue', 'jacket', 'with', 'many', 'distant', 'mountains', 'in', 'the', 'background']
# tokens ['A', 'smiling', 'hiker', 'poses', 'on', 'top', 'of', 'a', 'snow-covered', 'mountain']
# tokens ['A', 'little', 'girl', 'in', 'a', 'green', 'coat', 'and', 'a', 'boy', 'holding', 'a', 'red', 'sled', 'walk', 'in', 'the', 'snow', '.']
# tokens ['Child', 'wearing', 'a', 'Green', 'Bay', 'coat', 'carrying', 'a', 'red', 'sled', 'behind', 'a', 'child', 'in', 'a', 'green', 'and', 'black', 'coat', '.']
# tokens ['Two', 'children', 'and', 'walking', 'through', 'the', 'snow', 'carrying', 'a', 'sled', '.']
# tokens ['Two', 'small', 'children', 'in', 'snow', 'clothes', 'are', 'walking', 'through', 'the', 'snow', 'while', 'one', 'carries', 'a', 'red', 'sled']
# tokens ['two', 'young', 'kids', 'walking', 'towards', 'the', 'sidewalk', 'out', 'of', 'the', 'snow', '.']
# tokens ['A', 'climber', 'wearing', 'a', 'red', 'shirt', 'is', 'climbing', 'a', 'rock', 'face', 'on', 'a', 'snowy', 'day', '.']
# tokens ['A', 'man', 'in', 'a', 'red', 'shirt', 'climbing', 'a', 'rock', 'with', 'his', 'bare', 'hands', '.']
# tokens ['A', 'man', 'is', 'climbing', 'over', 'a', 'short', 'but', 'sheer', 'rocky', 'cliff', '.']
# tokens ['A', 'mean', 'wearing', 'a', 'red', 'shirt', 'clinging', 'to', 'a', 'rock', 'face', '.']
# tokens ['A', 'person', 'scales', 'a', 'rock', '.']
# tokens ['A', 'black', 'and', 'brown', 'dog', 'attempts', 'to', 'catch', 'a', 'red', 'ball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'brown', 'and', 'black', 'dog', 'approaching', 'a', 'red', 'ball', '.']
# tokens ['A', 'brown', 'and', 'black', 'dog', 'is', 'trying', 'to', 'catch', 'a', 'red', 'ball', 'in', 'its', 'mouth', '.']
# tokens ['A', 'dog', 'with', 'mouth', 'open', 'to', 'catch', 'the', 'red', 'ball', '.']
# tokens ['A', 'tan', 'and', 'black', 'dog', 'opens', 'its', 'mouth', 'for', 'a', 'red', 'ball', '.']
# tokens ['A', 'climber', 'is', 'making', 'his', 'way', 'up', 'a', 'snowy', 'mountainside', '.']
# tokens ['a', 'lone', 'person', 'jumping', 'through', 'the', 'air', 'from', 'one', 'snowy', 'mountain', 'to', 'another', '.']
# tokens ['A', 'man', 'doing', 'tricks', 'in', 'the', 'snow', '.']
# tokens ['A', 'man', 'dressed', 'in', 'snow-gear', 'takes', 'a', 'leap', 'into', 'a', 'snow-covered', 'ravine', '.']
# tokens ['People', 'jump', 'over', 'a', 'mountain', 'crevasse', 'on', 'a', 'rope', '.']
# tokens ['People', 'on', 'laptops', 'in', 'front', 'pf', 'a', 'large', 'window', '.']
# tokens ['There', 'are', 'two', 'men', 'and', 'one', 'female', 'sitting', 'down', 'and', 'looking', 'at', 'their', 'laptops', 'in', 'front', 'of', 'a', 'window', '.']
# tokens ['Three', 'people', 'at', 'with', 'their', 'backs', 'to', 'the', 'camera', 'at', 'an', 'internet', 'bar', '.']
# tokens ['Three', 'people', 'are', 'sitting', 'at', 'a', 'counter', 'using', 'laptop', 'computers', '.']
# tokens ['Three', 'people', 'work', 'on', 'their', 'laptops', 'inside', 'a', 'store', '.']
# tokens ['A', 'group', 'of', 'hikers', 'climb', 'rocky', 'terrain', '.']
# tokens ['Five', 'backpackers', 'hiking', 'along', 'a', 'rocky', 'slope', '.']
# tokens ['five', 'hikers', 'walk', 'down', 'the', 'hillside', '.']
# tokens ['Five', 'people', 'with', 'backpacks', 'hiking', 'down', 'a', 'rocky', 'hill', '.']
# tokens ['The', 'hikers', 'descend', 'on', 'the', 'mountain', '.']
# tokens ['A', 'brown', 'and', 'black', 'dog', 'fetching', 'a', 'tennis', 'ball', 'in', 'a', 'lake', '.']
# tokens ['A', 'dog', 'in', 'water', 'with', 'its', 'head', 'cocked', 'to', 'the', 'side', 'looking', 'at', 'a', 'ball', '.']
# tokens ['A', 'dog', 'is', 'running', 'through', 'the', 'water', 'chasing', 'after', 'a', 'ball', '.']
# tokens ['A', 'dog', 'is', 'shaking', 'off', 'water', 'in', 'a', 'lake', 'as', 'a', 'red', 'and', 'green', 'tennis', 'ball', 'floats', 'by', '.']
# tokens ['A', 'dog', 'playing', 'with', 'a', 'ball', 'in', 'water']
# tokens ['A', 'black', 'and', 'brown', 'dog', 'in', 'a', 'grassy', ',', 'well-lit', 'area', 'with', 'his', 'mouth', 'partially', 'open', '.']
# tokens ['A', 'dog', 'running', 'fast', 'with', 'his', 'ears', 'flying', '.']
# tokens ['Black', 'and', 'brown', 'dog', 'with', 'mouth', 'open', 'upright', 'on', 'green', 'grass', '.']
# tokens ['The', 'black', 'and', 'brown', 'dog', 'is', 'running', 'on', 'the', 'grass', '.']
# tokens ['The', 'black', 'and', 'brown', 'dog', 'is', 'running', 'with', 'something', 'in', 'its', 'mouth', '.']
# tokens ['A', 'dog', 'in', 'a', 'life', 'jacket', 'sitting', 'on', 'a', 'boat', 'with', 'a', 'man', 'in', 'the', 'cockpit', '.']
# tokens ['A', 'man', 'looking', 'at', 'his', 'small', 'white', 'dog', 'wearing', 'an', 'orange', 'life', 'jacket']
# tokens ['a', 'shite', 'dog', 'in', 'an', 'orange', 'life', 'vest', 'looking', 'at', 'a', 'man', 'in', 'a', 'blue', 'shirt', 'while', 'riding', 'in', 'a', 'boat', '.']
# tokens ['A', 'white', 'dog', 'in', 'a', 'life', 'jacket', 'looks', 'at', 'a', 'man', 'in', 'a', 'boat', '.']
# tokens ['A', 'white', 'dog', 'with', 'a', 'life', 'vest', 'accompanies', 'a', 'man', 'in', 'a', 'boat', '.']
# tokens ['a', 'boy', 'wears', 'a', 'red', 'coat', '.']
# tokens ['A', 'child', 'in', 'a', 'red', 'coat', 'stands', 'near', 'a', 'funny', 'decoration', '.']
# tokens ['A', 'child', 'wearing', 'a', 'coat', 'looks', 'back', 'at', 'someone', '.']
# tokens ['The', 'boy', 'is', 'dressed', 'in', 'a', 'red', 'coat', 'and', 'stands', 'next', 'to', 'a', 'statue', '.']
# ...
# tokens ['two', 'men', 'roll', 'a', 'huge', 'ball', '.']
# tokens ['Two', 'workers', 'in', 'orange', 'and', 'black', 'set', 'up', 'bubble']
# tokens ['A', 'baby', 'is', 'trying', 'to', 'eat', 'a', 'large', 'red', 'plastic', 'toy', 'outdoors', '.']
# tokens ['A', 'blonde', 'infant', 'chewing', 'on', 'a', 'red', 'toy', '.']
# tokens ['A', 'blonde', 'toddler', 'placing', 'his', 'mouth', 'on', 'the', 'edge', 'of', 'a', 'red', 'plastic', 'toy', '.']
# tokens ['A', 'child', 'plays', 'with', 'a', 'toy', 'in', 'the', 'grass', '.']
# tokens ['A', 'child', 'with', 'his', 'mouth', 'on', 'a', 'red', 'plastic', 'toy', '.']
# tokens ['A', 'man', 'in', 'red', 'swim', 'trunks', 'is', 'jumping', 'onto', 'a', 'bodyboard', '.']
# tokens ['A', 'man', 'in', 'red', 'trunks', 'flies', 'through', 'the', 'air', 'with', 'a', 'boogie', 'board', '.']
# tokens ['A', 'man', 'with', 'a', 'wake-board', 'is', 'diving', 'over', 'a', 'surface', 'that', 'is', 'not', 'water', '.']
# tokens ['A', 'shirtless', 'man', 'bodysurfs', '.']
# tokens ['Man', 'is', 'diving', 'onto', 'his', 'wakeboard', '.']
# tokens ['A', 'closeup', 'of', 'a', 'man', 'holding', 'a', 'baby', 'wearing', 'a', 'blue', 'shirt', '.']
# tokens ['A', 'man', 'holds', 'a', 'chubby', 'baby', 'with', 'pink', 'cheeks', 'and', 'blue', 'shirt', '.']
# tokens ['A', 'man', 'in', 'black', 'holds', 'a', 'baby', '.']
# tokens ['Ever', 'since', 'his', 'baby', 'girl', 'started', 'coming', 'to', 'the', 'arcade', 'with', 'him', ',', 'the', 'dad', 'enjoys', 'watching', 'others', 'play', 'his', 'favorite', 'pinball', 'game', '.']
# tokens ['The', 'man', 'is', 'holding', 'a', 'baby', 'near', 'a', 'carnival', 'game', '.']
# tokens ['a', 'dog', 'jumps', 'into', 'the', 'pond', '.']
# tokens ['A', 'dog', 'leaping', 'into', 'the', 'water', 'near', 'a', 'motorboat', '.']
# tokens ['A', 'light', 'colored', 'dog', 'jumping', 'off', 'the', 'back', 'of', 'a', 'boat', 'into', 'the', 'water', '.']
# tokens ['A', 'tan', 'dog', 'jumping', 'off', 'of', 'a', 'boat', 'into', 'the', 'water', '.']
# tokens ['The', 'yellow', 'dog', 'is', 'jumping', 'off', 'of', 'a', 'ship', 'into', 'the', 'water', '.']
# tokens ['A', 'boy', 'jumping', 'off', 'of', 'a', 'dock', 'while', 'his', 'friend', 'watches']
# tokens ['Two', 'boys', 'are', 'climbing', 'a', 'wooden', 'platform', 'and', 'jumping', 'into', 'a', 'river', '.']
# tokens ['Two', 'boys', 'jumping', 'off', 'the', 'pier', 'into', 'the', 'water', '.']
# tokens ['Two', 'boys', 'preparing', 'to', 'jump', 'off', 'a', 'pier', 'located', 'on', 'a', 'large', 'body', 'of', 'water', '.']
# tokens ['Two', 'children', 'jump', 'off', 'the', 'dock', 'into', 'the', 'lake', '.']
# tokens ['A', 'brown', 'dog', 'is', 'running', 'over', 'snow', 'near', 'leafless', 'trees', '.']
# tokens ['A', 'brown', 'dog', 'runs', 'across', 'a', 'snowy', 'field', '.']
# tokens ['A', 'dog', 'is', 'running', 'through', 'the', 'snow', '.']
# tokens ['A', 'dog', 'runs', 'through', 'the', 'snow', '.']
# tokens ['A', 'medium', 'sized', 'brown', 'dog', 'is', 'running', 'through', 'an', 'open', 'white', 'wooded', 'area', '.']
# tokens ['Hikers', 'cross', 'a', 'bridge', 'over', 'a', 'fast', 'moving', 'stream', 'and', 'rocky', 'scenery', '.']
# tokens ['People', 'crossing', 'a', 'long', 'bridge', 'over', 'a', 'canyon', 'with', 'a', 'river', '.']
# tokens ['People', 'walk', 'across', 'a', 'rope', 'bridge', 'over', 'a', 'rocky', 'stream', '.']
# tokens ['Some', 'hikers', 'are', 'crossing', 'a', 'wood', 'and', 'wire', 'bridge', 'over', 'a', 'river', '.']
# tokens ['Three', 'people', 'are', 'looking', 'across', 'a', 'rope', 'and', 'wood', 'bridge', 'over', 'a', 'river', '.']
# tokens ['A', 'hiker', 'is', 'walking', 'along', 'a', 'path', 'at', 'the', 'foot', 'of', 'some', 'snowcapped', 'mountains', '.']
# tokens ['A', 'man', 'walks', 'near', 'mountains', '.']
# tokens ['A', 'man', 'with', 'ski', 'poles', 'stands', 'in', 'front', 'of', 'a', 'mountain', '.']
# tokens ['The', 'person', 'is', 'walking', 'in', 'the', 'mountains', '.']
# tokens ['The', 'skier', 'is', 'looking', 'at', 'the', 'snowcapped', 'mountains', '.']
# tokens ['A', 'group', 'of', 'people', 'gather', 'on', 'a', 'balcony', '.']
# tokens ['A', 'group', 'of', 'people', 'standing', 'on', 'a', 'balcony', 'in', 'a', 'very', 'modern', 'setting', '.']
# tokens ['a', 'group', 'of', 'people', 'standing', 'on', 'a', 'small', 'balcony', 'of', 'a', 'large', 'building']
# tokens ['A', 'group', 'of', 'people', 'stand', 'on', 'a', 'balcony', '.']
# tokens ['Four', 'people', 'ride', 'in', 'an', 'outdoor', 'elevator', '.']
# tokens ['Two', 'men', 'in', 'ethnic', 'dress', 'standing', 'in', 'a', 'barren', 'landscape', '.']
# tokens ['Two', 'men', 'in', 'keffiyahs', 'stand', 'next', 'to', 'car', 'in', 'the', 'desert', 'and', 'wave', 'at', 'a', 'passing', 'vehicle', '.']
# tokens ['Two', 'men', 'in', 'robes', 'wave', 'at', 'an', 'approaching', 'jeep', 'traveling', 'through', 'the', 'sand', '.']
# tokens ['Two', 'men', 'in', 'traditional', 'Arab', 'dress', 'standing', 'near', 'a', 'car', 'wave', 'at', 'an', 'SUV', 'in', 'the', 'desert', '.']
# tokens ['Two', 'people', 'with', 'head', 'coverings', 'stand', 'in', 'a', 'sandy', 'field', '.']
# tokens ['A', 'girl', 'all', 'in', 'black', 'and', 'white', ',', 'and', 'carrying', 'an', 'umbrella', ',', 'walks', 'down', 'the', 'street', ',', 'as', 'others', 'watch', '.']
# tokens ['A', 'girl', 'dressed', 'in', 'black', 'and', 'white', 'with', 'mime', 'makeup', 'stands', 'in', 'the', 'middle', 'of', 'a', 'street', 'with', 'a', 'white', 'umbrella', 'and', 'black', 'top', 'hat', 'in', 'her', 'hand', '.']
# tokens ['a', 'performer', 'dancing', 'in', 'the', 'streets', 'wearing', 'an', 'exotic', 'outfit']
# tokens ['a', 'woman', 'with', 'a', 'shaved', 'head', 'dressed', 'in', 'black', 'and', 'white', 'in', 'a', 'parade']
# tokens ['The', 'lady', 'in', 'the', 'street', 'is', 'wearing', 'a', 'white', 'and', 'black', 'costume', 'and', 'is', 'carrying', 'a', 'white', 'umbrella', '.']
# tokens ['A', 'little', 'kid', 'splashes', 'around', 'in', 'the', 'kiddie', 'pool', 'while', 'a', 'lady', 'watches', '.']
# tokens ['a', 'woman', 'dumping', 'water', 'on', 'a', 'small', 'child', 'who', 'is', 'in', 'a', 'pool']
# tokens ['A', 'woman', 'is', 'throwing', 'a', 'bucket', 'of', 'water', 'over', 'a', 'baby', 'in', 'the', 'paddling', 'pool', '.']
# tokens ['A', 'woman', 'is', 'throwing', 'water', 'on', 'a', 'child', 'in', 'a', 'plastic', 'swimming', 'pool', 'in', 'a', 'rural', 'area', '.']
# tokens ['I', 'child', 'slides', 'into', 'a', 'wading', 'pool', 'full', 'of', 'water', 'while', 'an', 'adult', 'tosses', 'a', 'bucket', 'of', 'water', 'on', 'them', '.']
# tokens ['A', 'calico', 'cat', 'raising', 'its', 'paws', 'towards', 'a', 'dog', 'with', 'an', 'open', 'mouth']
# tokens ['A', 'cat', 'swatting', 'at', 'a', 'doberman', 'dog']
# tokens ['A', 'dog', 'and', 'cat', 'are', 'fighting', 'on', 'a', 'chair', '.']
# tokens ['A', 'multicolor', 'cat', 'fighting', 'with', 'a', 'black', 'and', 'brown', 'dog', 'in', 'a', 'red', 'collar', '.']
# tokens ['The', 'yellow', 'and', 'black', 'cat', 'and', 'the', 'brown', 'and', 'black', 'dog', 'are', 'fighting', '.']
# tokens ['A', 'child', 'is', 'running', 'away', 'from', 'a', 'plastic', 'pool', 'and', 'an', 'adult', 'on', 'a', 'rural', 'setting', '.']
# tokens ['A', 'child', 'is', 'running', 'away', 'from', 'a', 'woman', 'standing', 'by', 'a', 'paddling', 'pool', '.']
# tokens ['A', 'child', 'playing', 'with', 'a', 'water', 'hose', 'while', 'a', 'woman', 'records', 'with', 'a', 'camcorder']
# tokens ['A', 'woman', 'and', 'her', 'son', 'are', 'playing', 'outside', 'by', 'a', 'kiddie', 'pool', '.']
# tokens ['A', 'woman', 'watches', 'a', 'child', 'play', 'near', 'a', 'small', 'pool', '.']
# tokens ['a', 'blond', 'boy', 'petting', 'a', 'tiger']
# tokens ['A', 'boy', 'pets', 'a', 'sleeping', 'tiger', '.']
# tokens ['A', 'boy', 'pets', 'a', 'sleeping', 'tiger', 'while', 'another', 'tiger', 'sleeps', 'behind', 'him', '.']
# tokens ['A', 'little', 'blonde', 'boy', 'is', 'petting', 'a', 'resting', 'tiger', '.']
# tokens ['A', 'little', 'boy', 'is', 'petting', 'a', 'tiger', 'that', 'is', 'laying', 'down', '.']
# tokens ['A', 'man', 'mountain', 'climbing', 'up', 'an', 'icy', 'mountain', '.']
# tokens ['An', 'climber', 'is', 'ascending', 'an', 'ice', 'covered', 'rock', 'face', '.']
# tokens ['A', 'person', 'in', 'orange', 'climbs', 'a', 'sheer', 'cliff', 'face', 'covered', 'in', 'snow', 'and', 'ice', '.']
# tokens ['Person', 'in', 'a', 'yellow', 'jacket', 'is', 'climbing', 'up', 'snow', 'covered', 'rocks', '.']
# tokens ['There', 'is', 'a', 'climber', 'scaling', 'a', 'snowy', 'mountainside', '.']
# tokens ['A', 'woman', 'and', 'a', 'little', 'girl', 'sit', 'on', 'desert', 'rock', '.']
# tokens ['A', 'young', 'girl', 'and', 'older', 'person', 'are', 'sitting', 'near', 'the', 'top', 'of', 'a', 'rock', 'formation', '.']
# tokens ['two', 'girls', 'sit', 'on', 'a', 'large', 'rock', '.']
# tokens ['Two', 'people', 'are', 'sitting', 'on', 'a', 'huge', 'rock', 'formation', '.']
# tokens ['Two', 'people', 'sit', 'in', 'the', 'distance', 'on', 'an', 'unusual', 'rock', 'formation', '.']
# tokens ['A', 'cart', 'containig', 'two', 'men', 'being', 'pulled', 'by', 'horses', 'in', 'the', 'rain', '.']
# tokens ['a', 'horse', 'driven', 'carriage', 'running', 'through', 'a', 'rainstorm', '.']
# tokens ['Black', 'and', 'white', 'horses', 'carry', 'a', 'cart', 'with', 'people', 'through', 'the', 'rain', '.']
# tokens ['People', 'enjoy', 'a', 'horse', 'draw', 'open', 'carriage', 'in', 'the', 'rain', '.']
# tokens ['The', 'horses', 'pull', 'the', 'carriage', ',', 'holding', 'people', 'and', 'a', 'dog', ',', 'through', 'the', 'rain', '.']
# tokens ['A', 'brown', 'dog', 'in', 'a', 'pink', 'shirt', 'runs', 'through', 'a', 'field', '.']
# tokens ['A', 'hairy', 'dog', 'with', 'a', 'pink', 'shirt', 'running', 'through', 'a', 'field']
# tokens ['A', 'long-haired', 'dog', 'wearing', 'a', 'pink', 'vest', 'and', 'running']
# tokens ['Brown', 'dog', 'in', 'a', 'pink', 'sweater', 'runs', 'on', 'yellow', 'grass', '.']
# tokens ['Dog', 'with', 'pink', 'jacket', 'running', 'in', 'field']
# tokens ['A', 'blonde', 'child', 'swims', '.']
# tokens ['A', 'boy', 'is', 'swimming', 'in', 'open', 'water', '.']
# tokens ['a', 'child', 'submerges', 'from', 'the', 'water', '.']
# tokens ['A', 'kid', 'comes', 'up', 'from', 'the', 'water', '.']
# tokens ['The', 'small', 'child', 'comes', 'up', 'from', 'underwater', '.']
# tokens ['Two', 'girls', 'are', 'walking', 'arm', 'in', 'arm', 'past', 'an', 'amusement', 'arcade', '.']
# tokens ['Two', 'girls', 'are', 'walking', 'away', 'from', 'the', 'camera', 'under', 'a', 'walkway', '.']
# tokens ['Two', 'girls', 'in', 'shorts', 'walk', 'towards', 'casino', 'signs', '.']
# tokens ['two', 'teenage', 'girls', 'walking', 'down', 'a', 'mall', 'breezeway', '.']
# tokens ['two', 'women', 'walk', 'on', 'the', 'sidewalk', '.']
# tokens ['A', 'group', 'of', 'six', 'children', 'sit', 'at', 'a', 'wooden', 'table', '.']
# tokens ['A', 'group', 'of', 'young', 'asian', 'children', 'pose', 'for', 'a', 'picture', 'at', 'a', 'table', '.']
# tokens ['Six', 'children', ',', 'all', 'with', 'black', 'hair', ',', 'sit', 'at', 'a', 'table', 'for', 'a', 'picture', '.']
# tokens ['Six', 'children', 'at', 'a', 'table', '.']
# tokens ['Six', 'small', 'children', 'sitting', 'at', 'a', 'desk', '.']
# tokens ['Two', 'brown', 'and', 'white', 'dogs', 'lift', 'their', 'ears', 'and', 'look', 'through', 'a', 'fence', '.']
# tokens ['Two', 'little', 'dogs', 'looking', 'out', 'of', 'their', 'cage', '.']
# tokens ['Two', 'small', 'dogs', 'are', 'in', 'a', 'cage', 'outside', '.']
# tokens ['Two', 'small', 'dogs', 'in', 'a', 'cage', '.']
# tokens ['Two', 'white', 'and', 'brown', 'dogs', 'up', 'against', 'a', 'fence', '.']
# tokens ['A', 'boy', 'goes', 'down', 'an', 'inflatable', 'slide', '.']
# tokens ['A', 'boy', 'in', 'red', 'slides', 'down', 'an', 'inflatable', 'ride', '.']
# tokens ['A', 'boy', 'is', 'sliding', 'down', 'in', 'a', 'red', 'shirt', '.']
# tokens ['A', 'child', 'going', 'down', 'an', 'inflatable', 'slide', '.']
# tokens ['A', 'young', 'boy', 'sliding', 'down', 'an', 'inflatable', ',', 'is', 'looking', 'off', 'camera', '.']
# tokens ['one', 'brown', 'and', 'white', 'dog', 'chasing', 'a', 'black', 'and', 'white', 'dog', 'through', 'the', 'grass']
# tokens ['The', 'two', 'dogs', 'are', 'running', 'through', 'the', 'grass', '.']
# tokens ['Two', 'cocker', 'spaniels', 'running', 'through', 'the', 'grass', '.']
# tokens ['Two', 'dogs', 'are', 'running', 'through', 'a', 'green', 'yard']
# tokens ['Two', 'dogs', 'are', 'running', 'through', 'the', 'grass', 'near', 'a', 'house', 'and', 'trees', '.']
# tokens ['A', 'girl', 'in', 'a', 'pool', 'wearing', 'goggles', 'and', 'surrounded', 'by', 'other', 'children']
# tokens ['A', 'girl', 'in', 'green', 'goggles', 'in', 'a', 'pool', 'with', 'three', 'other', 'children', '.']
# tokens ['A', 'red', 'haired', 'girl', 'making', 'a', 'peace', 'sign', 'is', 'wearing', 'neon', 'green', 'glasses', 'and', 'floaties', 'and', 'playing', 'in', 'the', 'pool', 'with', 'other', 'kids', '.']
# tokens ['A', 'red-headed', 'girl', 'offers', 'the', 'peace', 'sign', 'as', 'she', 'swims', 'in', 'the', 'pool', 'with', 'floaties', '.']
# tokens ['A', 'young', 'girl', 'with', 'goggles', 'and', 'floaties', 'poses', 'for', 'the', 'camera', 'as', 'she', 'plays', 'in', 'a', 'pool', '.']
# tokens ['A', 'black', 'dog', 'has', 'a', 'dumbbell', 'in', 'his', 'mouth', '.']
# tokens ['A', 'black', 'dog', 'has', 'a', 'dumbbell', 'in', 'his', 'mouth', 'looking', 'at', 'the', 'person', 'wearing', 'blue', '.']
# tokens ['A', 'black', 'dog', 'holding', 'a', 'weight', 'in', 'its', 'mouth', 'stands', 'next', 'to', 'a', 'person', '.']
# tokens ['A', 'black', 'dog', 'holds', 'a', 'small', 'white', 'dumbbell', 'in', 'its', 'mouth', '.']
# tokens ['The', 'black', 'dog', 'has', 'a', 'toy', 'in', 'its', 'mouth', 'and', 'a', 'person', 'stands', 'nearby', '.']
# tokens ['A', 'man', 'does', 'a', 'wheelie', 'on', 'his', 'bicycle', 'on', 'the', 'sidewalk', '.']
# tokens ['A', 'man', 'is', 'doing', 'a', 'wheelie', 'on', 'a', 'mountain', 'bike', '.']
# tokens ['A', 'man', 'on', 'a', 'bicycle', 'is', 'on', 'only', 'the', 'back', 'wheel', '.']
# tokens ['Asian', 'man', 'in', 'orange', 'hat', 'is', 'popping', 'a', 'wheelie', 'on', 'his', 'bike', '.']
# tokens ['Man', 'on', 'a', 'bicycle', 'riding', 'on', 'only', 'one', 'wheel', '.']
# tokens ['A', 'group', 'is', 'sitting', 'around', 'a', 'snowy', 'crevasse', '.']
# tokens ['A', 'group', 'of', 'people', 'sit', 'atop', 'a', 'snowy', 'mountain', '.']
# tokens ['A', 'group', 'of', 'people', 'sit', 'in', 'the', 'snow', 'overlooking', 'a', 'mountain', 'scene', '.']
# tokens ['Five', 'children', 'getting', 'ready', 'to', 'sled', '.']
# tokens ['Five', 'people', 'are', 'sitting', 'together', 'in', 'the', 'snow', '.']
# tokens ['A', 'grey', 'bird', 'stands', 'majestically', 'on', 'a', 'beach', 'while', 'waves', 'roll', 'in', '.']
# tokens ['A', 'large', 'bird', 'stands', 'in', 'the', 'water', 'on', 'the', 'beach', '.']
# tokens ['A', 'tall', 'bird', 'is', 'standing', 'on', 'the', 'sand', 'beside', 'the', 'ocean', '.']
# tokens ['A', 'water', 'bird', 'standing', 'at', 'the', 'ocean', "'s", 'edge', '.']
# tokens ['A', 'white', 'crane', 'stands', 'tall', 'as', 'it', 'looks', 'out', 'upon', 'the', 'ocean', '.']
# tokens ['A', 'person', 'stands', 'near', 'golden', 'walls', '.']
# tokens ['a', 'woman', 'behind', 'a', 'scrolled', 'wall', 'is', 'writing']
# tokens ['A', 'woman', 'standing', 'near', 'a', 'decorated', 'wall', 'writes', '.']
# tokens ['The', 'walls', 'are', 'covered', 'in', 'gold', 'and', 'patterns', '.']
# tokens ['Woman', 'writing', 'on', 'a', 'pad', 'in', 'room', 'with', 'gold', ',', 'decorated', 'walls', '.']
# tokens ['A', 'man', 'in', 'a', 'pink', 'shirt', 'climbs', 'a', 'rock', 'face']
# tokens ['A', 'man', 'is', 'rock', 'climbing', 'high', 'in', 'the', 'air', '.']
# tokens ['A', 'person', 'in', 'a', 'red', 'shirt', 'climbing', 'up', 'a', 'rock', 'face', 'covered', 'in', 'assist', 'handles', '.']
# tokens ['A', 'rock', 'climber', 'in', 'a', 'red', 'shirt', '.']
# tokens ['A', 'rock', 'climber', 'practices', 'on', 'a', 'rock', 'climbing', 'wall', '.']

# %%
def train_val_split(caption_data, train_size=0.8, shuffle=True):
    """Split the captioning dataset into train and validation sets.

    Args:
        caption_data (dict): Dictionary containing the mapped caption data
        train_size (float): Fraction of all the full dataset to use as training data
        shuffle (bool): Whether to shuffle the dataset before splitting

    Returns:
        Traning and validation datasets as two separated dicts
    """

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())
    print(all_images[0:10])

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)
        print("after shuffle", all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)
    print(train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    # 4. Return the splits
    return training_data, validation_data


# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# ['Flicker8k_Dataset/1000268201_693b08cb0e.jpg', 'Flicker8k_Dataset/1001773457_577c3a7d70.jpg', 'Flicker8k_Dataset/1002674143_1b742ab4b8.jpg', 'Flicker8k_Dataset/1003163366_44323f5815.jpg', 'Flicker8k_Dataset/1007129816_e794419615.jpg', 'Flicker8k_Dataset/1007320043_627395c3d8.jpg', 'Flicker8k_Dataset/1009434119_febe49276a.jpg', 'Flicker8k_Dataset/1012212859_01547e3f17.jpg', 'Flicker8k_Dataset/1015118661_980735411b.jpg', 'Flicker8k_Dataset/1015584366_dfcec3c85a.jpg']
# after shuffle ['Flicker8k_Dataset/3459362347_c412ef9901.jpg', 'Flicker8k_Dataset/2080033499_6be742f483.jpg', 'Flicker8k_Dataset/506478284_7cf8bdbe36.jpg', 'Flicker8k_Dataset/861795382_5145ad433d.jpg', 'Flicker8k_Dataset/1342766791_1e72f92455.jpg', 'Flicker8k_Dataset/2192333873_2a0cbe849d.jpg', 'Flicker8k_Dataset/554774472_b5d165ff69.jpg', 'Flicker8k_Dataset/3700322513_50f0d45bfa.jpg', 'Flicker8k_Dataset/2860035355_3fe7a5caa4.jpg', 'Flicker8k_Dataset/2353088412_5e5804c6f5.jpg', 'Flicker8k_Dataset/109202756_b97fcdc62c.jpg', 'Flicker8k_Dataset/3501206996_477be0f318.jpg', 'Flicker8k_Dataset/2156726763_034ecd2e39.jpg', 'Flicker8k_Dataset/3726629271_7639634703.jpg', 'Flicker8k_Dataset/2934379210_4e399e3cac.jpg', 'Flicker8k_Dataset/2754271176_4a2cda8c15.jpg', 'Flicker8k_Dataset/526661994_21838fc72c.jpg', 'Flicker8k_Dataset/2565703445_dd6899bc0e.jpg', 'Flicker8k_Dataset/3203742047_6a55065411.jpg', 'Flicker8k_Dataset/3262647146_a53770a21d.jpg', 'Flicker8k_Dataset/3360930596_1e75164ce6.jpg', 'Flicker8k_Dataset/3378553508_e37e281d25.jpg', 'Flicker8k_Dataset/1428578577_82864facae.jpg', 'Flicker8k_Dataset/2647049174_0fb47cee2e.jpg', 'Flicker8k_Dataset/86412576_c53392ef80.jpg', 'Flicker8k_Dataset/436009777_440c7679a1.jpg', 'Flicker8k_Dataset/3084010872_cbc3ea8239.jpg', 'Flicker8k_Dataset/267015208_d80b3eb94d.jpg', 'Flicker8k_Dataset/1388346434_524d0b6dfa.jpg', 'Flicker8k_Dataset/2939475047_84585ea45c.jpg', 'Flicker8k_Dataset/525968880_82623392d1.jpg', 'Flicker8k_Dataset/3562816250_6e14d436b1.jpg', 'Flicker8k_Dataset/2052202553_373dad145b.jpg', 'Flicker8k_Dataset/3296150666_aae2f64348.jpg', 'Flicker8k_Dataset/3568197730_a071d7595b.jpg', 'Flicker8k_Dataset/2516317118_10ae66b87a.jpg', 'Flicker8k_Dataset/2780087302_6a77658cbf.jpg', 'Flicker8k_Dataset/3674521435_89ff681074.jpg', 'Flicker8k_Dataset/3420469425_2980b4cd30.jpg', 'Flicker8k_Dataset/3503623999_bbd5dcfb18.jpg', 'Flicker8k_Dataset/2338627102_6708a9b4fd.jpg', 'Flicker8k_Dataset/2140305708_591d10b54d.jpg', 'Flicker8k_Dataset/1072153132_53d2bb1b60.jpg', 'Flicker8k_Dataset/2426781076_e3f4d2685c.jpg', 'Flicker8k_Dataset/3381584882_341ee3092f.jpg', 'Flicker8k_Dataset/2926233397_71e617f3a3.jpg', 'Flicker8k_Dataset/482882719_165722082d.jpg', 'Flicker8k_Dataset/3189002057_3ef61b803e.jpg', 'Flicker8k_Dataset/3639363462_bcdb21de29.jpg', 'Flicker8k_Dataset/3165936115_cb4017d94e.jpg', 'Flicker8k_Dataset/3639845565_be547c38ba.jpg', 'Flicker8k_Dataset/485741580_ab523fa657.jpg', 'Flicker8k_Dataset/2036407732_d5a0389bba.jpg', 'Flicker8k_Dataset/2307807200_91fa29cba1.jpg', 'Flicker8k_Dataset/3544312930_3a0b8d70c1.jpg', 'Flicker8k_Dataset/2584412512_6767593f24.jpg', 'Flicker8k_Dataset/2364394224_c17b09e035.jpg', 'Flicker8k_Dataset/1765164972_92dac06fa9.jpg', 'Flicker8k_Dataset/3656225270_cdf89e3240.jpg', 'Flicker8k_Dataset/1801063894_60bce29e19.jpg', 'Flicker8k_Dataset/697778778_b52090709d.jpg', 'Flicker8k_Dataset/415657941_454d370721.jpg', 'Flicker8k_Dataset/3415003392_139c0f3586.jpg', 'Flicker8k_Dataset/3142055158_01b9e4caa4.jpg', 'Flicker8k_Dataset/3029463004_c2d2c8f404.jpg', 'Flicker8k_Dataset/3371567346_b6522efdb8.jpg', 'Flicker8k_Dataset/2574509968_e4692ae169.jpg', 'Flicker8k_Dataset/532131603_c82d454c8a.jpg', 'Flicker8k_Dataset/639120223_7db6bdb61f.jpg', 'Flicker8k_Dataset/3375920709_ef7370fa09.jpg', 'Flicker8k_Dataset/2052702658_da1204f6d1.jpg', 'Flicker8k_Dataset/2752341621_54490b9b09.jpg', 'Flicker8k_Dataset/2980445969_a86f4e6a0e.jpg', 'Flicker8k_Dataset/186346360_541047336f.jpg', 'Flicker8k_Dataset/2111360187_d2505437b7.jpg', 'Flicker8k_Dataset/69710415_5c2bfb1058.jpg', 'Flicker8k_Dataset/3333039854_461329aac2.jpg', 'Flicker8k_Dataset/2467803152_70eeca1334.jpg', 'Flicker8k_Dataset/2276120079_4f235470bc.jpg', 'Flicker8k_Dataset/835415474_7b7f2a9768.jpg', 'Flicker8k_Dataset/3701291852_373ea46bb6.jpg', 'Flicker8k_Dataset/3592968286_b63c81bcd2.jpg', 'Flicker8k_Dataset/3242007318_01e82171aa.jpg', 'Flicker8k_Dataset/2869491449_1041485a6b.jpg', 'Flicker8k_Dataset/3641456303_c50c33337b.jpg', 'Flicker8k ...
# 6114
# Number of training samples:  6114
# Number of validation samples:  1529

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")
print(strip_chars)
# Out:
# !"#$%&'()*+,-./:;=?@[\]^_`{|}~

# %%
custom_standardization("Stay Hungry, Stay Foolish")
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'stay hungry stay foolish'>

# %%
vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# %%
vectorization.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  'a',
#  '<start>',
#  '<end>',
#  'in',
#  'the',
#  'on',
#  'is',
#  'and',
#  'dog',
#  'with',
#  'man',
#  'of',
#  'two',
#  'white',
#  'black',
#  'boy',
#  'are',
#  'woman',
#  'girl',
#  'to',
#  'wearing',
#  'at',
#  'people',
#  'water',
#  'red',
#  'young',
#  'brown',
#  'an',
#  'his',
#  'blue',
#  'dogs',
#  'through',
#  'running',
#  'playing',
#  'while',
#  'down',
#  'standing',
#  'little',
#  'ball',
#  'shirt',
#  'grass',
#  'child',
#  'person',
#  'snow',
#  'jumping',
#  'over',
#  'front',
#  'sitting',
#  'three',
#  'holding',
#  'field',
#  'small',
#  'up',
#  'large',
#  'by',
#  'group',
#  'green',
#  'yellow',
#  'walking',
#  'one',
#  'her',
#  'children',
#  'men',
#  'into',
#  'beach',
#  'air',
#  'near',
#  'mouth',
#  'jumps',
#  'street',
#  'another',
#  'runs',
#  'for',
#  'its',
#  'from',
#  'riding',
#  'bike',
#  'stands',
#  'as',
#  'girls',
#  'outside',
#  'out',
#  'off',
#  'other',
#  'orange',
#  'next',
#  'rock',
#  'looking',
#  'pink',
#  'play',
#  'player',
#  'pool',
#  'camera',
#  'their',
#  'jacket',
#  'hat',
#  'boys',
#  'around',
#  'some',
#  'women',
#  'behind',
#  'toy',
#  'dirt',
#  'sits',
#  'background',
#  'soccer',
#  'has',
#  'mountain',
#  'wall',
#  'walks',
#  'dressed',
#  'plays',
#  'crowd',
#  'along',
#  'stand',
#  'building',
#  'park',
#  'looks',
#  'climbing',
#  'four',
#  'across',
#  'top',
#  'face',
#  'football',
#  'stick',
#  'holds',
#  'sand',
#  'grassy',
#  'rides',
#  'ocean',
#  'smiling',
#  'swimming',
#  'hill',
#  'tennis',
#  'carrying',
#  'skateboard',
#  'car',
#  'doing',
#  'each',
#  'baby',
#  'bicycle',
#  'snowy',
#  'picture',
#  'tree',
#  'together',
#  'hair',
#  's',
#  'it',
#  'area',
#  'jump',
#  'road',
#  'tan',
#  'trick',
#  'that',
#  'him',
#  'basketball',
#  'back',
#  'catch',
#  'shorts',
#  'head',
#  'bench',
#  'swing',
#  'race',
#  'sidewalk',
#  'sit',
#  'run',
#  'helmet',
#  'game',
#  'ground',
#  'fence',
#  'dress',
#  'something',
#  'kids',
#  'lake',
#  'frisbee',
#  'hand',
#  'being',
#  'city',
#  'path',
#  'ramp',
#  'wave',
#  'walk',
#  'purple',
#  'several',
#  'slide',
#  'skateboarder',
#  'covered',
#  'side',
#  'there',
#  'wooden',
#  'high',
#  'baseball',
#  'boat',
#  'big',
#  'posing',
#  'track',
#  'long',
#  'watches',
#  'sunglasses',
#  'players',
#  'coat',
#  'rocks',
#  'trees',
#  'look',
#  'uniform',
#  'pants',
#  'table',
#  'ride',
#  'rope',
#  'them',
#  'watching',
#  'motorcycle',
#  'grey',
#  'under',
#  'rocky',
#  'beside',
#  'towards',
#  'dark',
#  'couple',
#  'river',
#  'suit',
#  'watch',
#  'hands',
#  'arms',
#  'does',
#  'sign',
#  'snowboarder',
#  'above',
#  'older',
#  'lady',
#  'ice',
#  'horse',
#  'racing',
#  'colorful',
#  'woods',
#  'jeans',
#  'striped',
#  'pose',
#  'onto',
#  'who',
#  'midair',
#  'leaps',
#  'taking',
#  'climbs',
#  'yard',
#  'playground',
#  'mountains',
#  'he',
#  'glasses',
#  'guy',
#  'asian',
#  'against',
#  'collar',
#  'performing',
#  'cliff',
#  'cap',
#  'bird',
#  'blond',
#  'blonde',
#  'laying',
#  'body',
#  'smiles',
#  'chasing',
#  'open',
#  'many',
#  'kid',
#  'after',
#  'surfer',
#  'fountain',
#  'rider',
#  'wet',
#  'team',
#  'hockey',
#  'surrounded',
#  'skier',
#  'brick',
#  'inside',
#  'old',
#  'flying',
#  'shore',
#  'biker',
#  'takes',
#  'outdoors',
#  'edge',
#  'colored',
#  'toddler',
#  'during',
#  'away',
#  'others',
#  'guitar',
#  'light',
#  'trying',
#  'very',
#  'hanging',
#  'forest',
#  'middle',
#  'backpack',
#  'steps',
#  'someone',
#  'night',
#  'bed',
#  'pole',
#  'five',
#  'nearby',
#  'floor',
#  'object',
#  'gray',
#  'about',
#  'outfit',
#  'tshirt',
#  'trail',
#  'going',
#  'talking',
#  'making',
#  'tall',
#  'arm',
#  'line',
#  'flowers',
#  'toward',
#  'surfboard',
#  'poses',
#  'whilst',
#  'waves',
#  'sky',
#  'past',
#  'leaves',
#  'haired',
#  'dancing',
#  'swinging',
#  'bridge',
#  'day',
#  'board',
#  'leaping',
#  'eating',
#  'this',
#  'course',
#  'window',
#  'outdoor',
#  'all',
#  'legs',
#  'splashing',
#  'shallow',
#  'plastic',
#  'leash',
#  'clothes',
#  'chair',
#  'carries',
#  'costume',
#  'clothing',
#  'bag',
#  'stone',
#  'room',
#  'house',
#  'fighting',
#  'obstacle',
#  'sliding',
#  'ready',
#  'catches',
#  'getting',
#  'adult',
#  'swings',
#  'bright',
#  'between',
#  'climber',
#  'bathing',
#  'shirts',
#  'waiting',
#  'they',
#  'concrete',
#  'winter',
#  'trampoline',
#  'mud',
#  'lawn',
#  'wears',
#  'gear',
#  'railing',
#  'sweater',
#  'stream',
#  'sled',
#  'pulling',
#  'fire',
#  'uniforms',
#  'stairs',
#  'metal',
#  'train',
#  'store',
#  'skateboarding',
#  'jersey',
#  'distance',
#  'tongue',
#  'skiing',
#  'number',
#  'throwing',
#  'sandy',
#  'male',
#  'lot',
#  'golden',
#  'get',
#  'catching',
#  'tries',
#  'sun',
#  'set',
#  'gets',
#  'bar',
#  'swims',
#  'rail',
#  'flies',
#  'overlooking',
#  'female',
#  'drink',
#  'couch',
#  'adults',
#  'wooded',
#  'tricks',
#  'chases',
#  'shirtless',
#  'lying',
#  'flag',
#  'fishing',
#  'tire',
#  'swim',
#  'makes',
#  'animal',
#  'vest',
#  'reading',
#  'trunks',
#  'cellphone',
#  'puppy',
#  'pond',
#  'drinking',
#  'busy',
#  'smile',
#  'she',
#  'puddle',
#  'laughing',
#  'dock',
#  'upside',
#  'ski',
#  'shopping',
#  'performs',
#  'slides',
#  'huge',
#  'sunset',
#  'food',
#  'leaning',
#  'eyes',
#  'bubbles',
#  'truck',
#  'surfing',
#  'shoes',
#  'kayak',
#  'snowboard',
#  'photo',
#  'hats',
#  'american',
#  'right',
#  'nose',
#  'flip',
#  'bikes',
#  'waterfall',
#  'coming',
#  'climb',
#  'stunt',
#  'or',
#  'no',
#  'life',
#  'horses',
#  'hold',
#  'family',
#  'elderly',
#  'cart',
#  'scarf',
#  'hurdle',
#  'umbrella',
#  'lone',
#  'deep',
#  'bat',
#  'tent',
#  'muddy',
#  'left',
#  'wetsuit',
#  'restaurant',
#  'hiker',
#  'harness',
#  'flags',
#  'falling',
#  'view',
#  'skating',
#  'setting',
#  'paper',
#  'mask',
#  'greyhound',
#  'feet',
#  'dry',
#  'biting',
#  'bags',
#  'take',
#  'skis',
#  'court',
#  'vehicle',
#  'like',
#  'equipment',
#  'dresses',
#  'closeup',
#  'book',
#  'surf',
#  'raft',
#  'pile',
#  'crowded',
#  'bus',
#  'both',
#  'six',
#  'ledge',
#  'skirt',
#  'goal',
#  'german',
#  'cigarette',
#  'cement',
#  'bmx',
#  'sweatshirt',
#  'structure',
#  'skate',
#  'guys',
#  'goes',
#  'driving',
#  'be',
#  'airborne',
#  'tank',
#  'inflatable',
#  'goggles',
#  'costumes',
#  'canoe',
#  'bottle',
#  'wood',
#  'splashes',
#  'shaking',
#  'diving',
#  'subway',
#  'fallen',
#  'cyclist',
#  'parking',
#  'kicking',
#  'ears',
#  'slope',
#  'shepherd',
#  'gathered',
#  'dance',
#  'blanket',
#  'turn',
#  'tunnel',
#  'teenage',
#  'smaller',
#  'short',
#  'ring',
#  'pictures',
#  'parade',
#  'kick',
#  'buildings',
#  'smoking',
#  'leather',
#  'have',
#  'full',
#  'fight',
#  'faces',
#  'boots',
#  'balls',
#  'backyard',
#  'throws',
#  'silver',
#  'hit',
#  'cat',
#  'band',
#  'sunny',
#  'outfits',
#  'low',
#  'kicks',
#  'jackets',
#  'hiking',
#  'fluffy',
#  'event',
#  'chairs',
#  'cars',
#  'bull',
#  'using',
#  'stuffed',
#  'stage',
#  'microphone',
#  'graffiti',
#  'surface',
#  'piece',
#  'bucket',
#  'blowing',
#  'beard',
#  'wheel',
#  'tube',
#  'sports',
#  'glass',
#  'bicyclist',
#  'volleyball',
#  'scooter',
#  'held',
#  'gold',
#  'drinks',
#  'door',
#  'bikini',
#  'suits',
#  'steep',
#  'sleeping',
#  'rugby',
#  'pushing',
#  'cow',
#  'box',
#  'bald',
#  'wrestling',
#  'throw',
#  'swimsuit',
#  'sticks',
#  'statue',
#  'painted',
#  'furry',
#  'cowboy',
#  'corner',
#  'pointing',
#  'paint',
#  'net',
#  'crossing',
#  'attempting',
#  'staring',
#  'shot',
#  'sheep',
#  'same',
#  'motorcyclist',
#  'hugging',
#  'hangs',
#  'bunch',
#  'wrestle',
#  'make',
#  'log',
#  'leg',
#  'leans',
#  'hind',
#  'few',
#  'bicycles',
#  'wading',
#  'show',
#  'points',
#  'facing',
#  'desert',
#  'beige',
#  'attempts',
#  'sprinkler',
#  'spectators',
#  'onlookers',
#  'lays',
#  'kissing',
#  'go',
#  'flower',
#  'cup',
#  'below',
#  'beautiful',
#  'underwater',
#  'sticking',
#  'snowboarding',
#  'police',
#  'poles',
#  'hoop',
#  'fish',
#  'eats',
#  'attached',
#  'waving',
#  'rain',
#  'racket',
#  'party',
#  'gym',
#  'gather',
#  'fast',
#  'dances',
#  'talks',
#  'seat',
#  'racetrack',
#  'naked',
#  'motocross',
#  'garden',
#  'end',
#  'competition',
#  'wings',
#  'wide',
#  'teams',
#  'signs',
#  'rolling',
#  'puppies',
#  'mohawk',
#  'ladies',
#  'headband',
#  'empty',
#  'clear',
#  'birds',
#  'toys',
#  'snowcovered',
#  'seated',
#  'racer',
#  'prepares',
#  'platform',
#  'phone',
#  'paddling',
#  'handstand',
#  'gravel',
#  'fenced',
#  'do',
#  'cross',
#  'branch',
#  'wear',
#  'way',
#  'public',
#  'pavement',
#  'market',
#  'hits',
#  'heads',
#  'bride',
#  'base',
#  'which',
#  'traffic',
#  'pushes',
#  'having',
#  'chewing',
#  'thrown',
#  'softball',
#  'school',
#  'neck',
#  'kitchen',
#  'just',
#  'splash',
#  'scene',
#  'rural',
#  'rough',
#  'reads',
#  'plaid',
#  'filled',
#  'drives',
#  'downhill',
#  'cream',
#  'bottom',
#  'among',
#  'urban',
#  'teeth',
#  'smoke',
#  'shop',
#  'plants',
#  'hose',
#  'display',
#  'dirty',
#  'different',
#  'before',
#  'barefoot',
#  'wrestler',
#  'stadium',
#  'skateboards',
#  'resting',
#  'painting',
#  'lit',
#  'lies',
#  'landscape',
#  'indoor',
#  'creek',
#  'close',
#  'carpet',
#  'blows',
#  'bars',
#  'african',
#  'waits',
#  'wait',
#  'rapids',
#  'paved',
#  'moving',
#  'gun',
#  'fall',
#  'carnival',
#  'block',
#  'bearded',
#  'talk',
#  'skates',
#  'showing',
#  'shoulder',
#  'seen',
#  'races',
#  'paddle',
#  'opposing',
#  'onstage',
#  'lights',
#  'lap',
#  'hula',
#  'foot',
#  'chase',
#  'boats',
#  'beer',
#  'animals',
#  'video',
#  'says',
#  'reaching',
#  'poodle',
#  'photograph',
#  'matching',
#  'greyhounds',
#  'goalie',
#  'foreground',
#  'deck',
#  'can',
#  'bandanna',
#  'atv',
#  'younger',
#  'wire',
#  'where',
#  'unicycle',
#  'staircase',
#  'shooting',
#  'santa',
#  'ropes',
#  'pipe',
#  'parked',
#  'newspaper',
#  'multicolored',
#  'motorbike',
#  'mother',
#  'instruments',
#  'hitting',
#  'helmets',
#  'headphones',
#  'hay',
#  'gloves',
#  'fair',
#  'ear',
#  'wheelie',
#  'try',
#  'tie',
#  'third',
#  'spray',
#  'spotted',
#  'shoulders',
#  'shakes',
#  'match',
#  'grinding',
#  'funny',
#  'fly',
#  'floating',
#  'flight',
#  'falls',
#  'cricket',
#  'bubble',
#  'atop',
#  'art',
#  'amusement',
#  'teenagers',
#  'singing',
#  'retriever',
#  'reaches',
#  'pulls',
#  'pulled',
#  'preparing',
#  'plate',
#  'outstretched',
#  'mouths',
#  'larger',
#  'kite',
#  'hole',
#  'giant',
#  'follows',
#  'chain',
#  'bushes',
#  'bank',
#  'balloon',
#  'audience',
#  'alongside',
#  'wedding',
#  'runner',
#  'rowing',
#  'rodeo',
#  'raises',
#  'pack',
#  'jeep',
#  'formation',
#  'duck',
#  'denim',
#  'curly',
#  'covering',
#  'christmas',
#  'appears',
#  'alone',
#  'spinning',
#  'row',
#  'putting',
#  'picnic',
#  'paddles',
#  'muzzle',
#  'martial',
#  'kneeling',
#  'hoodie',
#  'himself',
#  'hikers',
#  'finger',
#  'enjoys',
#  'digging',
#  'backwards',
#  'terrain',
#  'station',
#  'pier',
#  'parachute',
#  'lined',
#  'jumped',
#  'hooded',
#  'handrail',
#  'cold',
#  'balancing',
#  'backs',
#  'sniffing',
#  'shaggy',
#  'shadow',
#  'safety',
#  'roller',
#  'puts',
#  'purse',
#  'pull',
#  'owner',
#  'music',
#  'ladder',
#  'giving',
#  'gives',
#  'gate',
#  'counter',
#  'violin',
#  'underneath',
#  'tackle',
#  'stop',
#  'shows',
#  'seven',
#  'playfully',
#  'necklace',
#  'muzzled',
#  'machine',
#  'licking',
#  'laughs',
#  'indoors',
#  'half',
#  'enjoying',
#  'construction',
#  'brightly',
#  'bites',
#  'backpacks',
#  'writing',
#  'wheelchair',
#  'terrier',
#  'taken',
#  'surfs',
#  'splashed',
#  'skiers',
#  'sea',
#  'round',
#  'rollerblades',
#  'riders',
#  'perform',
#  'mound',
#  'makeup',
#  'leap',
#  'jungle',
#  'hillside',
#  'friend',
#  'fingers',
#  'decorated',
#  'crouches',
#  'collie',
#  'coats',
#  'cloth',
#  'break',
#  'tug',
#  'step',
#  'spots',
#  'pigeons',
#  'paws',
#  'passing',
#  'military',
#  'made',
#  'lean',
#  'kayaking',
#  'hoops',
#  'homeless',
#  'hang',
#  'float',
#  'fetch',
#  'ducks',
#  'doorway',
#  'cone',
#  'computer',
#  'competing',
#  'clouds',
#  'bite',
#  'bikers',
#  'barrier',
#  'balances',
#  'without',
#  ...]

# %%
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset

# %%
# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3), include_top=False, weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model

# %%
class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

# %%
class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM, sequence_length=SEQ_LENGTH, vocab_size=VOCAB_SIZE
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)

# %%
class ImageCaptioningModel(keras.Model):
    def __init__(
        self, cnn_model, encoder, decoder, num_captions_per_image=5, image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]

# %%
cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step

# %%
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="none"
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# Fit the model
caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/30
# 96/96 [==============================] - 128s 971ms/step - loss: 34.2299 - acc: 0.0840 - val_loss: 24.6622 - val_acc: 0.2204
# Epoch 2/30
# 96/96 [==============================] - 69s 714ms/step - loss: 22.3099 - acc: 0.2535 - val_loss: 19.7185 - val_acc: 0.3243
# Epoch 3/30
# 96/96 [==============================] - 70s 724ms/step - loss: 18.7902 - acc: 0.3301 - val_loss: 17.7065 - val_acc: 0.3538
# Epoch 4/30
# 96/96 [==============================] - 71s 739ms/step - loss: 17.1594 - acc: 0.3590 - val_loss: 16.7578 - val_acc: 0.3694
# Epoch 5/30
# 96/96 [==============================] - 70s 732ms/step - loss: 16.1273 - acc: 0.3767 - val_loss: 16.1447 - val_acc: 0.3829
# Epoch 6/30
# 96/96 [==============================] - 71s 738ms/step - loss: 15.3407 - acc: 0.3911 - val_loss: 15.7426 - val_acc: 0.3919
# Epoch 7/30
# 96/96 [==============================] - 70s 729ms/step - loss: 14.7381 - acc: 0.4046 - val_loss: 15.4543 - val_acc: 0.3985
# Epoch 8/30
# 96/96 [==============================] - 70s 727ms/step - loss: 14.2167 - acc: 0.4141 - val_loss: 15.2680 - val_acc: 0.4025
# Epoch 9/30
# 96/96 [==============================] - 70s 724ms/step - loss: 13.7574 - acc: 0.4238 - val_loss: 15.1832 - val_acc: 0.4055
# Epoch 10/30
# 96/96 [==============================] - 69s 718ms/step - loss: 13.3435 - acc: 0.4329 - val_loss: 14.9892 - val_acc: 0.4089
# Epoch 11/30
# 96/96 [==============================] - 70s 730ms/step - loss: 12.9688 - acc: 0.4404 - val_loss: 14.9865 - val_acc: 0.4096
# Epoch 12/30
# 96/96 [==============================] - 71s 733ms/step - loss: 12.6169 - acc: 0.4488 - val_loss: 14.9649 - val_acc: 0.4105
# Epoch 13/30
# 96/96 [==============================] - 70s 727ms/step - loss: 12.2958 - acc: 0.4583 - val_loss: 14.9118 - val_acc: 0.4110
# Epoch 14/30
# 96/96 [==============================] - 69s 718ms/step - loss: 12.0006 - acc: 0.4644 - val_loss: 14.9330 - val_acc: 0.4131
# Epoch 15/30
# 96/96 [==============================] - 70s 726ms/step - loss: 11.7052 - acc: 0.4724 - val_loss: 14.9433 - val_acc: 0.4137
# Epoch 16/30
# 96/96 [==============================] - 70s 728ms/step - loss: 11.4491 - acc: 0.4785 - val_loss: 14.9627 - val_acc: 0.4143

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)


    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
generate_caption()
generate_caption()
generate_caption()
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  a man and a dog are running on the beach
# Predicted Caption:  a black and white dog is biting a black dog
# Predicted Caption:  a black and white dog is chasing a ball in a yard
# Predicted Caption:  a girl in a blue dress is blowing bubbles
# Predicted Caption:  a greyhound is racing on a track
# Predicted Caption:  a woman in a pink dress and a woman in a pink dress
# Predicted Caption:  a man sits on a rock wall
# Predicted Caption:  a woman with a white shirt and sunglasses on her head
